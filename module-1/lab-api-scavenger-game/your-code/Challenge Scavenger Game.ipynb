# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
username = 'Laura-Foulon'
token = 'XXX'

url = 'https://api.github.com/repos/ironhack-labs/data-labs/forks'

headers = {'Authorization': 'token ' + token}

response = requests.get(url, headers)
results = response.json()
results
# Out:
# [{'id': 197140353,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxOTcxNDAzNTM=',
#   'name': 'data-labs',
#   'full_name': 'Tiviia/data-labs',
#   'private': False,
#   'owner': {'login': 'Tiviia',
#    'id': 51444790,
#    'node_id': 'MDQ6VXNlcjUxNDQ0Nzkw',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/51444790?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Tiviia',
#    'html_url': 'https://github.com/Tiviia',
#    'followers_url': 'https://api.github.com/users/Tiviia/followers',
#    'following_url': 'https://api.github.com/users/Tiviia/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Tiviia/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Tiviia/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Tiviia/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Tiviia/orgs',
#    'repos_url': 'https://api.github.com/users/Tiviia/repos',
# ...

# %%
df = pd.DataFrame(results)
df
# Out:
#                                           archive_url  archived  \
# 0   https://api.github.com/repos/Tiviia/data-labs/...     False
# 1   https://api.github.com/repos/carlarsmendes/dat...     False
# 2   https://api.github.com/repos/amartinezm90/data...     False
# 3   https://api.github.com/repos/pedro-munoz/data-...     False
# 4   https://api.github.com/repos/uaqro/data-labs/{...     False
# 5   https://api.github.com/repos/eduarde1/data-lab...     False
# 6   https://api.github.com/repos/Weslley-MS/data-l...     False
# 7   https://api.github.com/repos/jotapescabora/dat...     False
# 8   https://api.github.com/repos/GabrieleGoncalves...     False
# 9   https://api.github.com/repos/Guiaugustosilva/d...     False
# 10  https://api.github.com/repos/lenon51/data-labs...     False
# 11  https://api.github.com/repos/GBPadova/data-lab...     False
# 12  https://api.github.com/repos/isafloriano/data-...     False
# 13  https://api.github.com/repos/isabelalemos/data...     False
# ...

# %%
df.full_name[0:]
# Out:
# 0                Tiviia/data-labs
# 1         carlarsmendes/data-labs
# 2          amartinezm90/data-labs
# 3           pedro-munoz/data-labs
# 4                 uaqro/data-labs
# 5              eduarde1/data-labs
# 6            Weslley-MS/data-labs
# 7         jotapescabora/data-labs
# 8     GabrieleGoncalves/data-labs
# 9       Guiaugustosilva/data-labs
# 10              lenon51/data-labs
# 11             GBPadova/data-labs
# 12          isafloriano/data-labs
# 13         isabelalemos/data-labs
# 14         katiaiwasaki/data-labs
# 15    vanessaboaventura/data-labs
# 16              vmcarva/data-labs
# 17            carollmbg/data-labs
# 18          rzrodriguez/data-labs
# 19           IsisGuedes/data-labs
# 20             tchaguri/data-labs
# 21        kellyferreira/data-labs
# 22      kelsey-ironhack/data-labs
# 23              LTpablo/data-labs
# 24          gissellec16/data-labs
# 25             Gayushka/data-labs
# 26            sandrineh/data-labs
# ...

# %%
# Loop the JSON response to find out the language attribute of each fork. 
# Use an array to store the language attributes of each fork.

# %%
language = df['language'].unique()
print(language)
# Out:
# ['Jupyter Notebook']

# %%
# Avec une boucle

lg = [res['language'] for res in results]
print(set(lg))
# Out:
# {'Jupyter Notebook'}

# %%
# Challenge 2 (période plus longue car pas de commit)

url_2 = 'https://api.github.com/repos/ironhack-labs/data-labs/commits?since=2019-01-01&until=2019-07-17'

response_2 = requests.get(url_2, headers)
results_2 = response_2.json()
results_2
# Out:
# [{'sha': 'a8af4349e1f2525297e57293f8ee2bd38a59294f',
#   'node_id': 'MDY6Q29tbWl0MTQ3NjgzNTQwOmE4YWY0MzQ5ZTFmMjUyNTI5N2U1NzI5M2Y4ZWUyYmQzOGE1OTI5NGY=',
#   'commit': {'author': {'name': 'kbartonhenry',
#     'email': 'k.bartonhenry@gmail.com',
#     'date': '2019-07-03T07:37:34Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2019-07-03T07:37:34Z'},
#    'message': 'typo fix',
#    'tree': {'sha': '58da0b3f94798ee478a40cb43c1f928343f8cd5c',
#     'url': 'https://api.github.com/repos/ironhack-labs/data-labs/git/trees/58da0b3f94798ee478a40cb43c1f928343f8cd5c'},
#    'url': 'https://api.github.com/repos/ironhack-labs/data-labs/git/commits/a8af4349e1f2525297e57293f8ee2bd38a59294f',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
# ...

# %%
df_2 = pd.DataFrame(results_2)
df_2
# Out:
#                                                author  \
# 0   {'login': 'kbartonhenry', 'id': 22545329, 'nod...
# 1   {'login': 'kbartonhenry', 'id': 22545329, 'nod...
# 2   {'login': 'kbartonhenry', 'id': 22545329, 'nod...
# 3   {'login': 'kbartonhenry', 'id': 22545329, 'nod...
# 4   {'login': 'kbartonhenry', 'id': 22545329, 'nod...
# 5   {'login': 'kbartonhenry', 'id': 22545329, 'nod...
# 6   {'login': 'kbartonhenry', 'id': 22545329, 'nod...
# 7   {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# 8   {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# 9   {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# 10  {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# 11  {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# 12  {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# 13  {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# 14  {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# 15  {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# ...

# %%
flattened_data = json_normalize(results_2)
flattened_data
# Out:
#     author                                  author.avatar_url  \
# 0      NaN  https://avatars1.githubusercontent.com/u/22545...
# 1      NaN  https://avatars1.githubusercontent.com/u/22545...
# 2      NaN  https://avatars1.githubusercontent.com/u/22545...
# 3      NaN  https://avatars1.githubusercontent.com/u/22545...
# 4      NaN  https://avatars1.githubusercontent.com/u/22545...
# 5      NaN  https://avatars1.githubusercontent.com/u/22545...
# 6      NaN  https://avatars1.githubusercontent.com/u/22545...
# 7      NaN  https://avatars3.githubusercontent.com/u/16597...
# 8      NaN  https://avatars3.githubusercontent.com/u/16597...
# 9      NaN  https://avatars3.githubusercontent.com/u/16597...
# 10     NaN  https://avatars3.githubusercontent.com/u/16597...
# 11     NaN  https://avatars3.githubusercontent.com/u/16597...
# 12     NaN  https://avatars3.githubusercontent.com/u/16597...
# 13     NaN  https://avatars3.githubusercontent.com/u/16597...
# ...

# %%
df_2.shape[0]
# Out:
# 30

# %%
# Challenge 3

url_3 = 'https://api.github.com/repos/ironhack-datalabs/scavenger'

headers = {'Authorization': 'token ' + token}

response_3 = requests.get(url_3, headers)
results_3 = response_3.json()
results_3
# Out:
# {'id': 162375181,
#  'node_id': 'MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=',
#  'name': 'scavenger',
#  'full_name': 'ironhack-datalabs/scavenger',
#  'private': False,
#  'owner': {'login': 'ironhack-datalabs',
#   'id': 44225188,
#   'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4',
#   'avatar_url': 'https://avatars2.githubusercontent.com/u/44225188?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/ironhack-datalabs',
#   'html_url': 'https://github.com/ironhack-datalabs',
#   'followers_url': 'https://api.github.com/users/ironhack-datalabs/followers',
#   'following_url': 'https://api.github.com/users/ironhack-datalabs/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/ironhack-datalabs/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/ironhack-datalabs/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/ironhack-datalabs/subscriptions',
# ...

# %%
df_3 = pd.DataFrame(results_3)
df_3
# Out:
#                             id                           node_id       name  \
# avatar_url           162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# events_url           162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# followers_url        162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# following_url        162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# gists_url            162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# gravatar_id          162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# html_url             162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# id                   162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# login                162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# node_id              162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# organizations_url    162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# ...

# %%
ou sont les fichiers : get content
regarder le contenu de chaque fichier
trouver lencodage de chaque fichier

url avec /contents à la fin

scavenger file

1) boucler sur chacun des éléments de la racine du dossier - classer dans un ordre ascendant 
2) si c'est un dossier, appeler le get content
3) si fichier .scavenger, lire le contenu
4) stocker le contenu dans une liste
paths
get content sur le contenu de chacun de ces fichiers 
"content" > string en base 64 à décoder

# %%
"""CORRECTION
> Récupérer le contenu du repo > du dossier > des fichiers (le path)
> Trouver l'emplacement des fichiers
> Trier les fichiers dans l'ordre

On travaille sur la colonne Path dans le dataframe

On va faire une boucle dans laquelle on va recréer une URL pour aller chercher le dossier en question

l = [{'a':1, 'b':2}, {'a':4, 'b':5}]
pd.DataFrame(l)


"""
# Out:
# "CORRECTION\n> Récupérer le contenu du repo > du dossier > des fichiers (le path)\n> Trouver l'emplacement des fichiers\n> Trier les fichiers dans l'ordre\n\nOn travaille sur la colonne Path dans le dataframe\n\nOn va faire une boucle dans laquelle on va recréer une URL pour aller chercher le dossier en question\n\nl = [{'a':1, 'b':2}, {'a':4, 'b':5}]\npd.DataFrame(l)\n\n\n"

# %%
import pandas as pd

l = [{'a':1, 'b':2}, {'a':4, 'b':5}]
pd.DataFrame(l)
# Out:
#    a  b
# 0  1  2
# 1  4  5
