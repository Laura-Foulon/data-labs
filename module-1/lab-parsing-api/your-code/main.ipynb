# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
# your code here

url = 'https://www.zalando.fr/api/catalog/articles?brand_families=ADID&brands=AD7&brands=AD1&brands=AD5&categories=promo-chaussures-femme&limit=84&offset=85&price_to=150&sizes=39&sort=sale'

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here

# Import libraries

import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# Define the initial API endpoint URL

url = 'https://www.zalando.fr/api/catalog/articles?brand_families=ADID&brands=AD7&brands=AD1&brands=AD5&categories=promo-chaussures-femme&limit=84&offset=0&price_to=150&sizes=39&sort=sale'

user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36'
header = {'user-agent': user_agent}

response = requests.get(url,headers=header)
results = response.json()
results
# Out:
# {'total_count': 214,
#  'pagination': {'page_count': 3, 'current_page': 1, 'per_page': 84},
#  'sort': 'sale',
#  'articles': [{'sku': 'AD115O0BN-A11',
#    'name': 'GAZELLE - Baskets basses - footwear white',
#    'price': {'original': '94,95\xa0€',
#     'promotional': '90,00\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '40',
#     '42',
#     '44',
#     '46',
#     '48',
#     '37 1/3',
#     '38 2/3',
#     '39 1/3',
#     '40 2/3',
#     '41 1/3',
#     '42 2/3',
#     '43 1/3',
#     '45 1/3',
#     '46 2/3',
#     '47 1/3',
#     '48 2/3',
#     '49 1/3'],
#    'url_key': 'adidas-originals-gazelle-baskets-basses-footwear-white-ad115o0bn-a11',
#    'media': [{'path': 'AD/11/5O/0B/NA/11/AD115O0BN-A11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'adidas Originals',
# ...

# %%
# Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.

flattened_data = json_normalize(results)

flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1
# Out:
#    amount          brand_name  \
# 0     NaN    adidas Originals
# 1     NaN    adidas Originals
# 2     NaN    adidas Originals
# 3     NaN    adidas Originals
# 4     NaN    adidas Originals
# 5     NaN    adidas Originals
# 6     NaN    adidas Originals
# 7     NaN    adidas Originals
# 8     NaN    adidas Originals
# 9     NaN    adidas Originals
# 10    NaN    adidas Originals
# 11    NaN    adidas Originals
# 12    NaN    adidas Originals
# 13    NaN    adidas Originals
# 14    NaN    adidas Originals
# 15    NaN    adidas Originals
# 16    NaN    adidas Originals
# 17    NaN    adidas Originals
# 18    NaN    adidas Originals
# 19    NaN    adidas Originals
# 20    NaN    adidas Originals
# 21    NaN    adidas Originals
# 22    NaN    adidas Originals
# 23    NaN    adidas Originals
# 24    NaN    adidas Originals
# 25    NaN    adidas Originals
# 26    NaN    adidas Originals
# 27    NaN    adidas Originals
# 28    NaN    adidas Originals
# 29    NaN    adidas Originals
# ...

# %%
# Total number of pages

total_pages = results['pagination']['page_count']
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36'
header = {'user-agent': user_agent}

print('Total number of pages is:', total_pages)
# Out:
# Total number of pages is: 3

# %%
# Use a FOR loop to make requests for the additional pages from 2 to page count. 
# Append the data of each additional page to the flatterned data object.

df = pd.DataFrame()

for i in range(total_pages):
    k=84*i
    url=f'https://www.zalando.fr/api/catalog/articles?brand_families=ADID&brands=AD7&brands=AD1&brands=AD5&categories=promo-chaussures-femme&limit=84&offset={k}&price_to=150&sizes=39&sort=sale'
    response = requests.get(url, headers = header)
    results = response.json()
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1)

# %%
# Print and review the data you obtained.

df
# Out:
#               amount                  brand_name  \
# sku
# AD111A0MW-A11    NaN            adidas Originals
# AD111A0Q6-A11    NaN            adidas Originals
# AD115O0A5-B11    NaN            adidas Originals
# AD112B0H9-J11    NaN            adidas Originals
# AD115O09Q-C11    NaN            adidas Originals
# AD115B01Y-A11    NaN            adidas Originals
# AD111A0R1-M11    NaN            adidas Originals
# AD111A0OR-A11    NaN            adidas Originals
# AD111A0OR-C11    NaN            adidas Originals
# AD112B0H9-K11    NaN            adidas Originals
# AD112B0H9-Q11    NaN            adidas Originals
# AD111A0OQ-Q11    NaN            adidas Originals
# AD111A0Q3-Q11    NaN            adidas Originals
# AD111A0QU-B11    NaN            adidas Originals
# AD111A0QE-A11    NaN            adidas Originals
# AD111A0PQ-K11    NaN            adidas Originals
# AD111A0OD-J11    NaN            adidas Originals
# AD111A0QI-B11    NaN            adidas Originals
# ...

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# The trending brand

df.brand_name.value_counts().index[0]
# Out:
# 'adidas Originals'

# %%
# The product(s) with the highest discount

df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')

df['price.original'] = [x.replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [x.replace(',', '.') for x in df['price.promotional']]

df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)
df1=df.copy()

total_disc=df1.groupby(['brand_name']).sum().discount_amount

total_disc.sort_values(ascending=False).index[0]
# Out:
# 'adidas Originals'

# %%
# The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices)

# %%
total_disc[total_disc==0]
# Out:
# Series([], Name: discount_amount, dtype: float64)

# %%
print("All products have discounts.")
# Out:
# All products have discounts.
