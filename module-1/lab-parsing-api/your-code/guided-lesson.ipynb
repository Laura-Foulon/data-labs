# %% [markdown]
# # Parsing APIs Example

# %% [markdown]
# ## Intro
#
# Now we will take a look on a real data. When you parse data from web you will often meet API based web-pages.
#
# For example [zalando.fr](https://www.zalando.fr/accueil-homme/) is API based web-page.
#
# In this guided lab you will learn how to obtain the links from webpages and extract the data. Read through this doc, execute the cells in order and make sure you understand the explanations.
#
# *Note: This guided lab uses Google Chrome. Other browsers like Safari and Firefox have similar tools for developers but they work differently. To save your time in following this lab, it is strongly recommended that you install and use Google Chrome.*

# %% [markdown]
# ## Obtaining the link
#
# Zalando is discount e-store where you can buy clothes and accesories with discount. When we go to the web-page, we can choose different sections. First the general process will be shown using [Children section](https://www.zalando.fr/accueil-enfant/) as example.
#
# Here we will parse data about promotions only. Therefore, final output will be the DataFrame with all the goods under discount.
#
# [![Image from Gyazo](https://i.gyazo.com/fa4874d8e81c7570273bbfb853d66308.png)](https://gyazo.com/fa4874d8e81c7570273bbfb853d66308)
#
#
# We go to Promos page. Right click of mouse shows us a list of actions possible, from which we select Inspect.
#
# <img src='https://i.gyazo.com/bccbd11d69c9040dc98758d443e32052.png' width="400">
#
#
# You will see the menu dropdown on the right side or on the bottom of the window. There you should click on Network:
#
#
# [![Image from Gyazo](https://i.gyazo.com/f7e0db81cbfee67694183d1a7640bf81.png)](https://gyazo.com/f7e0db81cbfee67694183d1a7640bf81)

# %% [markdown]
# Right after the developer part will change showing the files behind the page. In order to obtain only useful files we select the following settings:
# 1. Preserve Log
# 2. Select XHR files.
#
# [![Image from Gyazo](https://i.gyazo.com/9a899d4441d9d93e795f79747f1e47d5.png)](https://gyazo.com/9a899d4441d9d93e795f79747f1e47d5)
#
# In order to obtain some files we need to scrool down and go forward to second page.
#
# [![Image from Gyazo](https://i.gyazo.com/0956eb3d5125075a236c9a439c7749c7.png)](https://gyazo.com/0956eb3d5125075a236c9a439c7749c7)
#
# In the Network panel you can see the following files being uploaded. All the data on the web-page is uploaded from the json file, which is one of the following. It is important to understand which file contains what kind of information.
#
# <a href="https://gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c"><img src="https://i.gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c.png" alt="Image from Gyazo" width="724.8"/></a>
#
# When you find what kind of information you need for the data to be uploaded you just test it. Here we need the article... file:
#
# <a href="https://gyazo.com/78b35bf492994b3f35c0564a21da202a"><img src="https://i.gyazo.com/78b35bf492994b3f35c0564a21da202a.png" alt="Image from Gyazo" width="727.2"/></a>
#
# When we test the link in Chrome inkognito mode we obtain the proper json file:
#
#
# <a href="https://gyazo.com/b60453fa98454fa29771c731a5174443"><img src="https://i.gyazo.com/b60453fa98454fa29771c731a5174443.png" alt="Image from Gyazo" width="1530.4"/></a>

# %% [markdown]
# In order to change the objects in the json file (kind of pagination), you need to change the offset (the number of the first element on the page). in fact, if you take a look on the link, it is easy to unerstand the structure of the link.
#
# # Reading the data
#
# Now the party rocks! When we know how can we obtain the data, it is not a problem to obtain the whole database with all the data from the web-page.
# In this lab you will collect your database of Zalando products. You select which goods you want to track. You can define as many filters to your data as you want. Just make sure that the data represents the filters.

# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
# Paste the url you obtained for your data
url='https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=84&sort=sale'

# %% [markdown]
# #### Collect first 84 object of the of the data (1st page)
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having *family_articles, flags, media* and *sizes* remaining lists (they are exceptions).

# %%
# Your code

user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36'
header = {'user-agent': user_agent}

response = requests.get(url,headers=header)                         
results = response.json()
results
# Out:
# {'total_count': 20298,
#  'pagination': {'page_count': 242, 'current_page': 2, 'per_page': 84},
#  'sort': 'sale',
#  'articles': [{'sku': 'GU153I00G-Q11',
#    'name': 'SMALL BACKPACK - Sac à dos - jet black',
#    'price': {'original': '59,95\xa0€',
#     'promotional': '36,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['One Size'],
#    'url_key': 'guess-small-backpack-sac-a-dos-gu153i00g-q11',
#    'media': [{'path': 'GU/15/3I/00/GQ/11/GU153I00G-Q11@3.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Guess',
#    'is_premium': False,
#    'family_articles': [{'sku': 'GU153I00G-Q11',
#      'url_key': 'guess-small-backpack-sac-a-dos-gu153i00g-q11',
#      'media': [{'path': 'GU/15/3I/00/GQ/11/GU153I00G-Q11@6.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'SMALL BACKPACK - Sac à dos - jet black',
#      'sizes': ['One Size'],
#      'price': {'original': '59,95\xa0€',
#       'promotional': '36,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-40%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': 'GU153I00G-J11',
#      'url_key': 'guess-small-backpack-sac-a-dos-slip-pink-gu153i00g-j11',
#      'media': [{'path': 'GU/15/3I/00/GJ/11/GU153I00G-J11@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'SMALL BACKPACK - Sac à dos - slip pink',
#      'sizes': ['One Size'],
#      'price': {'original': '59,95\xa0€',
#       'promotional': '59,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': []}],
#    'flags': [{'key': 'campaign',
#      'value': '-15% EXTRA',
#      'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#     {'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'accessoires'},
#   {'sku': 'ES124A08B-K11',
#    'name': 'PANTS - Jean slim - medium wash',
#    'price': {'original': '35,99\xa0€',
#     'promotional': '10,80\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['2a', '3a', '4a', '5a', '6a', '7a', '8a'],
#    'url_key': 'esprit-pants-jean-slim-medium-wash-es124a08b-k11',
#    'media': [{'path': 'ES/12/4A/08/BK/11/ES124A08B-K11@2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Esprit',
#    'is_premium': False,
#    'family_articles': [{'sku': 'ES124A08B-K11',
#      'url_key': 'esprit-pants-jean-slim-medium-wash-es124a08b-k11',
#      'media': [{'path': 'ES/12/4A/08/BK/11/ES124A08B-K11@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'PANTS - Jean slim - medium wash',
#      'sizes': ['2a', '3a', '4a', '5a', '6a', '7a', '8a'],
#      'price': {'original': '35,99\xa0€',
#       'promotional': '10,80\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': 'Jusqu’à -70%',
#        'tracking_value': 'discount rate'}]}],
#    'flags': [{'key': 'campaign',
#      'value': '-15% EXTRA',
#      'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'JAN24G00M-A11',
#    'name': 'JORHOTEL TEE CREW NECK JUNIOR - T-shirt imprimé - cloud dancer',
#    'price': {'original': '12,95\xa0€',
#     'promotional': '3,90\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['8a', '10a', '12a', '14a', '16a'],
#    'url_key': 'jackandjones-junior-jorhotel-tee-crew-neck-junior-t-shirt-imprime-jan24g00m-a11',
#    'media': [{'path': 'JA/N2/4G/00/MA/11/JAN24G00M-A11@5.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Jack & Jones Junior',
#    'is_premium': False,
#    'family_articles': [{'sku': 'JAN24G00M-A11',
#      'url_key': 'jackandjones-junior-jorhotel-tee-crew-neck-junior-t-shirt-imprime-jan24g00m-a11',
#      'media': [{'path': 'JA/N2/4G/00/MA/11/JAN24G00M-A11@5.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'JORHOTEL TEE CREW NECK JUNIOR - T-shirt imprimé - cloud dancer',
#      'sizes': ['8a', '10a', '12a', '14a', '16a'],
#      'price': {'original': '12,95\xa0€',
#       'promotional': '3,90\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-70%',
#        'tracking_value': 'discount rate'}]}],
#    'flags': [{'key': 'campaign',
#      'value': '-15% EXTRA',
#      'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#     {'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'NA823F0VH-K11',
#    'name': 'DRESS CAMPMINI - Robe en jersey - dark sapphire',
#    'price': {'original': '12,95\xa0€',
#     'promotional': '3,89\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['5a', '6a', '7a', '8a', '9a', '10a', '11a', '12a', '13a', '14a'],
#    'url_key': 'name-it-dress-campmini-robe-en-jersey-dark-sapphire-na823f0vh-k11',
#    'media': [{'path': 'NA/82/3F/0V/HK/11/NA823F0VH-K11@2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Name it',
#    'is_premium': False,
#    'family_articles': [{'sku': 'NA823F0VH-K11',
#      'url_key': 'name-it-dress-campmini-robe-en-jersey-dark-sapphire-na823f0vh-k11',
#      'media': [{'path': 'NA/82/3F/0V/HK/11/NA823F0VH-K11@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'DRESS CAMPMINI - Robe en jersey - dark sapphire',
#      'sizes': ['5a',
#       '6a',
#       '7a',
#       '8a',
#       '9a',
#       '10a',
#       '11a',
#       '12a',
#       '13a',
#       '14a'],
#      'price': {'original': '12,95\xa0€',
#       'promotional': '3,89\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-70%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': 'NA823F0VH-E11',
#      'url_key': 'name-it-dress-campmini-robe-en-jersey-na823f0vh-e11',
#      'media': [{'path': 'NA/82/3F/0V/HE/11/NA823F0VH-E11@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'DRESS CAMPMINI - Robe en jersey - cadmium yellow',
#      'sizes': ['5a',
#       '6a',
#       '7a',
#       '8a',
#       '9a',
#       '10a',
#       '11a',
#       '12a',
#       '13a',
#       '14a'],
#      'price': {'original': '12,95\xa0€',
#       'promotional': '7,12\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-45%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': 'NA823F0VH-J11',
#      'url_key': 'name-it-dress-campmini-robe-en-jersey-na823f0vh-j11',
#      'media': [{'path': 'NA/82/3F/0V/HJ/11/NA823F0VH-J11@7.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'DRESS CAMPMINI - Robe en jersey - strawberry pink',
#      'sizes': ['6a', '7a', '9a', '10a', '11a', '12a', '13a'],
#      'price': {'original': '12,95\xa0€',
#       'promotional': '5,18\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-60%',
#        'tracking_value': 'discount rate'}]}],
#    'flags': [{'key': 'campaign',
#      'value': '-15% EXTRA',
#      'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#     {'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'GP024G0FG-E11',
#    'name': 'T-shirt imprimé - canary yellow',
#    'price': {'original': '12,95\xa0€',
#     'promotional': '3,89\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['2a', '3a', '4a', '5a', '18-24m'],
#    'url_key': 'gap-march-t-shirt-imprime-gp024g0fg-e11',
#    'media': [{'path': 'GP/02/4G/0F/GE/11/GP024G0FG-E11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'GAP',
#    'is_premium': False,
#    'family_articles': [{'sku': 'GP024G0FG-E11',
#      'url_key': 'gap-march-t-shirt-imprime-gp024g0fg-e11',
#      'media': [{'path': 'GP/02/4G/0F/GE/11/GP024G0FG-E11@7.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'T-shirt imprimé - canary yellow',
#      'sizes': ['2a', '3a', '4a', '5a', '18-24m'],
#      'price': {'original': '12,95\xa0€',
#       'promotional': '3,89\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-70%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': 'GP024G0FG-H11',
#      'url_key': 'gap-march-t-shirt-imprime-gp024g0fg-h11',
#      'media': [{'path': 'GP/02/4G/0F/GH/11/GP024G0FG-H11@4.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'T-shirt imprimé - sport orange',
#      'sizes': ['5a', '18-24m'],
#      'price': {'original': '12,95\xa0€',
#       'promotional': '12,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': []},
#     {'sku': 'GP024G0FG-G11',
#      'url_key': 'gap-march-t-shirt-imprime-gp024g0fg-g11',
#      'media': [{'path': 'GP/02/4G/0F/GG/11/GP024G0FG-G11@7.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'T-shirt imprimé - new coral',
#      'sizes': ['4a', '5a', '18-24m'],
#      'price': {'original': '12,95\xa0€',
#       'promotional': '4,53\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-65%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': 'GP024G0FG-K11',
#      'url_key': 'gap-march-t-shirt-imprime-brilliant-blue-gp024g0fg-k11',
#      'media': [{'path': 'GP/02/4G/0F/GK/11/GP024G0FG-K11@6.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'T-shirt imprimé - brilliant blue',
#      'sizes': ['2a', '18-24m'],
#      'price': {'original': '12,95\xa0€',
#       'promotional': '6,47\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-50%',
#        'tracking_value': 'discount rate'}]}],
#    'flags': [{'key': 'campaign',
#      'value': '-15% EXTRA',
#      'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#     {'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'QU124L01V-K11',
#    'name': "Veste d'hiver - navy",
#    'price': {'original': '75,99\xa0€',
#     'promotional': '38,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['8a', '10a', '12a', '14a'],
#    'url_key': 'quiksilver-veste-dhiver-navy-qu124l01v-k11',
#    'media': [{'path': 'QU/12/4L/01/VK/11/QU124L01V-K11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Quiksilver',
#    'is_premium': False,
#    'family_articles': [{'sku': 'QU124L01V-K11',
#      'url_key': 'quiksilver-veste-dhiver-navy-qu124l01v-k11',
#      'media': [{'path': 'QU/12/4L/01/VK/11/QU124L01V-K11@11.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': "Veste d'hiver - navy",
#      'sizes': ['8a', '10a', '12a', '14a'],
#      'price': {'original': '75,99\xa0€',
#       'promotional': '38,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-50%',
#        'tracking_value': 'discount rate'}]}],
#    'flags': [{'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': '4BE23F082-A11',
#    'name': 'DRESS - Robe en jersey - white/black',
#    'price': {'original': '19,95\xa0€',
#     'promotional': '6,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['6-7a', '7-8a', '8-9a', '10-11a', '11-12a'],
#    'url_key': 'benetton-dress-robe-en-jersey-whiteblack-4be23f082-a11',
#    'media': [{'path': '4B/E2/3F/08/2A/11/4BE23F082-A11@2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Benetton',
#    'is_premium': False,
#    'family_articles': [{'sku': '4BE23F082-A11',
#      'url_key': 'benetton-dress-robe-en-jersey-whiteblack-4be23f082-a11',
#      'media': [{'path': '4B/E2/3F/08/2A/11/4BE23F082-A11@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'DRESS - Robe en jersey - white/black',
#      'sizes': ['6-7a', '7-8a', '8-9a', '10-11a', '11-12a'],
#      'price': {'original': '19,95\xa0€',
#       'promotional': '6,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-70%',
#        'tracking_value': 'discount rate'}]}],
#    'flags': [{'key': 'campaign',
#      'value': '-15% EXTRA',
#      'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#     {'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': '4BE24I023-K15',
#    'name': 'Chemise - blue',
#    'price': {'original': '19,95\xa0€',
#     'promotional': '9,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['3-4a',
#     '4-5a',
#     '6-7a',
#     '7-8a',
#     '8-9a',
#     '10-11a',
#     '11-12a',
#     '13-14a',
#     '18-24m'],
#    'url_key': 'benetton-chemise-blue-4be24i023-k15',
#    'media': [{'path': '4B/E2/4I/02/3K/15/4BE24I023-K15@2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Benetton',
#    'is_premium': False,
#    'family_articles': [{'sku': '4BE24I023-K15',
#      'url_key': 'benetton-chemise-blue-4be24i023-k15',
#      'media': [{'path': '4B/E2/4I/02/3K/15/4BE24I023-K15@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'Chemise - blue',
#      'sizes': ['3-4a',
#       '4-5a',
#       '6-7a',
#       '7-8a',
#       '8-9a',
#       '10-11a',
#       '11-12a',
#       '13-14a',
#       '18-24m'],
#      'price': {'original': '19,95\xa0€',
#       'promotional': '9,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-55%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': '4BE24I023-T11',
#      'url_key': 'benetton-chemise-multicolor-4be24i023-t11',
#      'media': [{'path': '4B/E2/4I/02/3T/11/4BE24I023-T11@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'Chemise - multicolor',
#      'sizes': ['3-4a', '6-7a', '7-8a', '11-12a', '18-24m'],
#      'price': {'original': '19,95\xa0€',
#       'promotional': '10,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-50%',
#        'tracking_value': 'discount rate'}]}],
#    'flags': [{'key': 'campaign',
#      'value': '-15% EXTRA',
#      'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#     {'key': 'discountRate',
#      'value': '-55%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'STF24C00P-T11',
#    'name': 'BERMUDAS 2 PACK - Short - indigo structure/sunset red',
#    'price': {'original': '17,95\xa0€',
#     'promotional': '5,40\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['4-6m', '7-9m', '10-12m', '13-18m'],
#    'url_key': 'staccato-bermudas-2-pack-short-indigo-structuresunset-red-stf24c00p-t11',
#    'media': [{'path': 'ST/F2/4C/00/PT/11/STF24C00P-T11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Staccato',
#    'is_premium': False,
#    'family_articles': [{'sku': 'STF24C00P-T11',
#      'url_key': 'staccato-bermudas-2-pack-short-indigo-structuresunset-red-stf24c00p-t11',
#      'media': [{'path': 'ST/F2/4C/00/PT/11/STF24C00P-T11@11.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'BERMUDAS 2 PACK - Short - indigo structure/sunset red',
#      'sizes': ['4-6m', '7-9m', '10-12m'],
#      'price': {'original': '17,95\xa0€',
#       'promotional': '5,40\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-70%',
#        'tracking_value': 'discount rate'}]}],
#    'flags': [{'key': 'campaign',
#      'value': '-15% EXTRA',
#      'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#     {'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': '4BE23F083-I11',
#    'name': 'DRESS - Robe en jersey - lilac',
#    'price': {'original': '19,95\xa0€',
#     'promotional': '6,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['3-4a',
#     '4-5a',
#     '6-7a',
#     '7-8a',
#     '8-9a',
#     '10-11a',
#     '11-12a',
#     '13-14a'],
#    'url_key': 'benetton-dress-robe-en-jersey-4be23f083-i11',
#    'media': [{'path': '4B/E2/3F/08/3I/11/4BE23F083-I11@2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Benetton',
#    'is_premium': False,
#    'family_articles': [{'sku': '4BE23F083-I11',
#      'url_key': 'benetton-dress-robe-en-jersey-4be23f083-i11',
#      'media': [{'path': '4B/E2/3F/08/3I/11/4BE23F083-I11@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'DRESS - Robe en jersey - lilac',
#      'sizes': ['3-4a',
#       '4-5a',
#       '6-7a',
#       '7-8a',
#       '8-9a',
#       '10-11a',
#       '11-12a',
#       '13-14a'],
#      'price': {'original': '19,95\xa0€',
#       'promotional': '6,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-70%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': '4BE23F083-J11',
#      'url_key': 'benetton-dress-robe-en-jersey-pinkblue-4be23f083-j11',
#      'media': [{'path': '4B/E2/3F/08/3J/11/4BE23F083-J11@6.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'DRESS - Robe en jersey - pink/blue',
#      'sizes': ['7-8a', '10-11a', '11-12a', '13-14a'],
#      'price': {'original': '19,95\xa0€',
#       'promotional': '8,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-60%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': '4BE23F083-A11',
#      'url_key': 'benetton-dress-robe-en-jersey-4be23f083-a11',
#      'media': [{'path': '4B/E2/3F/08/3A/11/4BE23F083-A11@9.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'DRESS - Robe en jersey - white/multicolor',
#      'sizes': ['3-4a', '4-5a', '10-11a', '11-12a'],
#      'price': {'original': '19,95\xa0€',
#       'promotional': '9,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-55%',
#        'tracking_value': 'discount rate'}]}],
#    'flags': [{'key': 'campaign',
#      'value': '-15% EXTRA',
#      'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#     {'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': '4BE23G0DU-K11',
#    'name': 'BASIC - Polo - dark blue',
#    'price': {'original': '17,95\xa0€',
#     'promotional': '7,18\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['3-4a',
#     '4-5a',
#     '6-7a',
#     '7-8a',
#     '8-9a',
#     '10-11a',
#     '11-12a',
#     '18-24m'],
#    'url_key': 'benetton-basic-polo-4be23g0du-k11',
#    'media': [{'path': '4B/E2/3G/0D/UK/11/4BE23G0DU-K11@4.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Benetton',
#    'is_premium': False,
#    'family_articles': [{'sku': '4BE23G0DU-K11',
#      'url_key': 'benetton-basic-polo-4be23g0du-k11',
#      'media': [{'path': '4B/E2/3G/0D/UK/11/4BE23G0DU-K11@4.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'BASIC - Polo - dark blue',
#      'sizes': ['3-4a',
#       '4-5a',
#       '6-7a',
#       '7-8a',
#       '8-9a',
#       '10-11a',
#       '11-12a',
#       '18-24m'],
#      'price': {'original': '17,95\xa0€',
#       'promotional': '7,18\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-60%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': '4BE23G0DU-I11',
#      'url_key': 'benetton-basic-polo-4be23g0du-i11',
#      'media': [{'path': '4B/E2/3G/0D/UI/11/4BE23G0DU-I11@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'BASIC - Polo - lilac',
#      'sizes': ['6-7a', '7-8a', '8-9a', '10-11a', '11-12a', '13-14a', '18-24m'],
#      'price': {'original': '17,95\xa0€',
#       'promotional': '7,18\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-60%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': '4BE23G0DU-A11',
#      'url_key': 'benetton-basic-polo-4be23g0du-a11',
#      'media': [{'path': '4B/E2/3G/0D/UA/11/4BE23G0DU-A11@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'BASIC - Polo - white',
#      'sizes': ['3-4a',
#       '4-5a',
#       '6-7a',
#       '7-8a',
#       '8-9a',
#       '10-11a',
#       '11-12a',
#       '18-24m'],
#      'price': {'original': '17,95\xa0€',
#       'promotional': '7,18\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-60%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': '4BE23G0DU-E11',
#      'url_key': 'benetton-basic-polo-yellow-4be23g0du-e11',
#      'media': [{'path': '4B/E2/3G/0D/UE/11/4BE23G0DU-E11@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'BASIC - Polo - yellow',
#      'sizes': ['3-4a',
#       '4-5a',
#       '6-7a',
#       '7-8a',
#       '8-9a',
#       '10-11a',
#       '11-12a',
#       '13-14a'],
#      'price': {'original': '17,95\xa0€',
#       'promotional': '8,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-55%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': '4BE23G0DU-J11',
#      'url_key': 'benetton-basic-polo-4be23g0du-j11',
#      'media': [{'path': '4B/E2/3G/0D/UJ/11/4BE23G0DU-J11@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'BASIC - Polo - pink',
#      'sizes': ['8-9a', '10-11a', '11-12a'],
#      'price': {'original': '17,95\xa0€',
#       'promotional': '6,28\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-65%',
#        'tracking_value': 'discount rate'}]}],
#    'flags': [{'key': 'campaign',
#      'value': '-15% EXTRA',
#      'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#     {'key': 'discountRate',
#      'value': '-60%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': '4BE23G0DU-A11',
#    'name': 'BASIC - Polo - white',
#    'price': {'original': '17,95\xa0€',
#     'promotional': '7,18\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['3-4a',
#     '4-5a',
#     '6-7a',
#     '7-8a',
#     '8-9a',
#     '10-11a',
#     '11-12a',
#     '18-24m'],
#    'url_key': 'benetton-basic-polo-4be23g0du-a11',
#    'media': [{'path': '4B/E2/3G/0D/UA/11/4BE23G0DU-A11@2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Benetton',
#    'is_premium': False,
#    'family_articles': [{'sku': '4BE23G0DU-A11',
#      'url_key': 'benetton-basic-polo-4be23g0du-a11',
#      'media': [{'path': '4B/E2/3G/0D/UA/11/4BE23G0DU-A11@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'BASIC - Polo - white',
#      'sizes': ['3-4a',
#       '4-5a',
#       '6-7a',
#       '7-8a',
#       '8-9a',
#       '10-11a',
#       '11-12a',
#       '18-24m'],
#      'price': {'original': '17,95\xa0€',
#       'promotional': '7,18\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-60%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': '4BE23G0DU-I11',
#      'url_key': 'benetton-basic-polo-4be23g0du-i11',
#      'media': [{'path': '4B/E2/3G/0D/UI/11/4BE23G0DU-I11@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'BASIC - Polo - lilac',
#      'sizes': ['6-7a', '7-8a', '8-9a', '10-11a', '11-12a', '13-14a', '18-24m'],
#      'price': {'original': '17,95\xa0€',
#       'promotional': '7,18\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-60%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': '4BE23G0DU-E11',
#      'url_key': 'benetton-basic-polo-yellow-4be23g0du-e11',
#      'media': [{'path': '4B/E2/3G/0D/UE/11/4BE23G0DU-E11@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'BASIC - Polo - yellow',
#      'sizes': ['3-4a',
#       '4-5a',
#       '6-7a',
#       '7-8a',
#       '8-9a',
#       '10-11a',
#       '11-12a',
#       '13-14a'],
#      'price': {'original': '17,95\xa0€',
#       'promotional': '8,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-55%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': '4BE23G0DU-K11',
#      'url_key': 'benetton-basic-polo-4be23g0du-k11',
#      'media': [{'path': '4B/E2/3G/0D/UK/11/4BE23G0DU-K11@4.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'BASIC - Polo - dark blue',
#      'sizes': ['3-4a',
#       '4-5a',
#       '6-7a',
#       '7-8a',
#       '8-9a',
#       '10-11a',
#       '11-12a',
#       '18-24m'],
#      'price': {'original': '17,95\xa0€',
#       'promotional': '7,18\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-60%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': '4BE23G0DU-J11',
#      'url_key': 'benetton-basic-polo-4be23g0du-j11',
#      'media': [{'path': '4B/E2/3G/0D/UJ/11/4BE23G0DU-J11@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'BASIC - Polo - pink',
#      'sizes': ['8-9a', '10-11a', '11-12a'],
#      'price': {'original': '17,95\xa0€',
#       'promotional': '6,28\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-65%',
#        'tracking_value': 'discount rate'}]}],
#    'flags': [{'key': 'campaign',
#      'value': '-15% EXTRA',
#      'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#     {'key': 'discountRate',
#      'value': '-60%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'N1243G09Y-G11',
#    'name': 'HOODIE - veste en sweat zippée - university red/black/white',
#    'price': {'original': '54,95\xa0€',
#     'promotional': '44,00\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['6-8a', '8-10a', '10-12a', '12-13a', '13-15a'],
#    'url_key': 'nike-performance-hoodie-veste-en-sweat-zippee-university-redblackwhite-n1243g09y-g11',
#    'media': [{'path': 'N1/24/3G/09/YG/11/N1243G09Y-G11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Performance',
#    'is_premium': False,
#    'family_articles': [{'sku': 'N1243G09Y-G11',
#      'url_key': 'nike-performance-hoodie-veste-en-sweat-zippee-university-redblackwhite-n1243g09y-g11',
#      'media': [{'path': 'N1/24/3G/09/YG/11/N1243G09Y-G11@8.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'HOODIE - veste en sweat zippée - university red/black/white',
#      'sizes': ['6-8a', '8-10a', '10-12a', '12-13a', '13-15a'],
#      'price': {'original': '54,95\xa0€',
#       'promotional': '44,00\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': 'Jusqu’à -20%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': 'N1243G09Y-C11',
#      'url_key': 'nike-performance-hoodie-veste-en-sweat-zippee-n1243g09y-c11',
#      'media': [{'path': 'N1/24/3G/09/YC/11/N1243G09Y-C11@5.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'HOODIE - veste en sweat zippée - indigo fog/obsidian/white',
#      'sizes': ['6-8a', '8-10a', '10-12a', '12-13a', '13-15a'],
#      'price': {'original': '54,95\xa0€',
#       'promotional': '35,45\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': 'Jusqu’à -35%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': 'N1243G09Y-Q11',
#      'url_key': 'nike-performance-hoodie-veste-en-sweat-zippee-n1243g09y-q11',
#      'media': [{'path': 'N1/24/3G/09/YQ/11/N1243G09Y-Q11@8.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'HOODIE - veste en sweat zippée - black/white',
#      'sizes': ['6-8a', '8-10a', '10-12a', '12-13a', '13-15a'],
#      'price': {'original': '54,95\xa0€',
#       'promotional': '40,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-25%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': 'N1243G09Y-J11',
#      'url_key': 'nike-performance-hoodie-veste-en-sweat-zippee-n1243g09y-j11',
#      'media': [{'path': 'N1/24/3G/09/YJ/11/N1243G09Y-J11@6.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'HOODIE - veste en sweat zippée - pink gaze/dark grey/black',
#      'sizes': ['6-8a', '8-10a', '10-12a', '12-13a', '13-15a'],
#      'price': {'original': '54,95\xa0€',
#       'promotional': '21,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': 'Jusqu’à -60%',
#        'tracking_value': 'discount rate'}]}],
#    'flags': [{'key': 'campaign',
#      'value': '-15% EXTRA',
#      'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'LA253M003-K11',
#    'name': 'BOY  - Chapeau - navy blue',
#    'price': {'original': '40,00\xa0€',
#     'promotional': '28,00\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['2a/5a', '6a/9a'],
#    'url_key': 'lacoste-boy-chapeau-navy-blue-la253m003-k11',
#    'media': [{'path': 'LA/25/3M/00/3K/11/LA253M003-K11@5.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Lacoste',
#    'is_premium': True,
#    'family_articles': [{'sku': 'LA253M003-K11',
#      'url_key': 'lacoste-boy-chapeau-navy-blue-la253m003-k11',
#      'media': [{'path': 'LA/25/3M/00/3K/11/LA253M003-K11@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'BOY  - Chapeau - navy blue',
#      'sizes': ['2a/5a', '6a/9a'],
#      'price': {'original': '40,00\xa0€',
#       'promotional': '28,00\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': 'Jusqu’à -30%',
#        'tracking_value': 'discount rate'}]}],
#    'flags': [{'key': 'campaign',
#      'value': '-15% EXTRA',
#      'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'accessoires'},
#   {'sku': 'NI114D0A9-C11',
#    'name': 'MD RUNNER 2 - Baskets basses - atmosphere grey/white',
#    'price': {'original': '44,95\xa0€',
#     'promotional': '31,46\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['28.5', '29.5', '30', '31.5', '32', '33', '33.5', '34', '35'],
#    'url_key': 'nike-sportswear-md-runner-2-baskets-basses-ni114d0a9-c11',
#    'media': [{'path': 'NI/11/4D/0A/9C/11/NI114D0A9-C11@3.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [{'sku': 'NI114D0A9-C11',
#      'url_key': 'nike-sportswear-md-runner-2-baskets-basses-ni114d0a9-c11',
#      'media': [{'path': 'NI/11/4D/0A/9C/11/NI114D0A9-C11@9.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'MD RUNNER 2 - Baskets basses - atmosphere grey/white',
#      'sizes': ['28.5', '29.5', '30', '31.5', '32', '33', '33.5', '34', '35'],
#      'price': {'original': '44,95\xa0€',
#       'promotional': '31,46\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': 'Jusqu’à -30%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': 'NI114D0A9-G12',
#      'url_key': 'nike-sportswear-md-runner-2-baskets-basses-ni114d0a9-g12',
#      'media': [{'path': 'NI/11/4D/0A/9G/12/NI114D0A9-G12@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'MD RUNNER 2 - Baskets basses - el dorado/white',
#      'sizes': ['28', '28.5', '29.5', '30', '31.5', '32', '33.5', '34', '35'],
#      'price': {'original': '44,95\xa0€',
#       'promotional': '44,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': []},
#     {'sku': 'NI114D0A9-G11',
#      'url_key': 'nike-sportswear-md-runner-2-baskets-basses-coral-stardustwhite-ni114d0a9-g11',
#      'media': [{'path': 'NI/11/4D/0A/9G/11/NI114D0A9-G11@10.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'MD RUNNER 2 - Baskets basses - coral stardust/white',
#      'sizes': ['33', '33.5', '34', '35'],
#      'price': {'original': '44,95\xa0€',
#       'promotional': '22,48\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': 'Jusqu’à -50%',
#        'tracking_value': 'discount rate'}]}],
#    'flags': [{'key': 'campaign',
#      'value': '-15% EXTRA',
#      'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe'},
#   {'sku': 'N1243K0B0-Q11',
#    'name': 'AIR MAX BODYSUIT BOOTIE SET - Survêtement - black',
#    'price': {'original': '19,95\xa0€',
#     'promotional': '12,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['6-12m'],
#    'url_key': 'nike-performance-air-max-bodysuit-bootie-set-survetement-n1243k0b0-q11',
#    'media': [{'path': 'N1/24/3K/0B/0Q/11/N1243K0B0-Q11@6.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Performance',
#    'is_premium': False,
#    'family_articles': [{'sku': 'N1243K0B0-Q11',
#      'url_key': 'nike-performance-air-max-bodysuit-bootie-set-survetement-n1243k0b0-q11',
#      'media': [{'path': 'N1/24/3K/0B/0Q/11/N1243K0B0-Q11@6.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'AIR MAX BODYSUIT BOOTIE SET - Survêtement - black',
#      'sizes': ['6-12m'],
#      'price': {'original': '19,95\xa0€',
#       'promotional': '12,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-35%',
#        'tracking_value': 'discount rate'}]}],
#    'flags': [{'key': 'campaign',
#      'value': '-15% EXTRA',
#      'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#     {'key': 'discountRate',
#      'value': '-35%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'ES123A099-G11',
#    'name': 'PANTS - Jean slim - watermelon',
#    'price': {'original': '25,95\xa0€',
#     'promotional': '7,80\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['2a', '3a', '4a', '5a', '6a', '7a', '8a'],
#    'url_key': 'esprit-pants-jean-slim-watermelon-es123a099-g11',
#    'media': [{'path': 'ES/12/3A/09/9G/11/ES123A099-G11@5.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Esprit',
#    'is_premium': False,
#    'family_articles': [{'sku': 'ES123A099-G11',
#      'url_key': 'esprit-pants-jean-slim-watermelon-es123a099-g11',
#      'media': [{'path': 'ES/12/3A/09/9G/11/ES123A099-G11@5.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'PANTS - Jean slim - watermelon',
#      'sizes': ['2a', '3a', '4a', '5a', '6a', '7a', '8a'],
#      'price': {'original': '25,95\xa0€',
#       'promotional': '7,80\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': 'Jusqu’à -70%',
#        'tracking_value': 'discount rate'}]}],
#    'flags': [{'key': 'campaign',
#      'value': '-15% EXTRA',
#      'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'SUF53I000-E11',
#    'name': 'GIRAFFE KIDS LUNCH BAG - Sac à main - yellow',
#    'price': {'original': '24,95\xa0€',
#     'promotional': '7,50\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['One Size'],
#    'url_key': 'sunnylife-giraffe-kids-lunch-bag-sac-a-main-yellow-suf53i000-e11',
#    'media': [{'path': 'SU/F5/3I/00/0E/11/SUF53I000-E11@3.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Sunnylife',
#    'is_premium': False,
#    'family_articles': [{'sku': 'SUF53I000-E11',
#      'url_key': 'sunnylife-giraffe-kids-lunch-bag-sac-a-main-yellow-suf53i000-e11',
#      'media': [{'path': 'SU/F5/3I/00/0E/11/SUF53I000-E11@11.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'GIRAFFE KIDS LUNCH BAG - Sac à main - yellow',
#      'sizes': ['One Size'],
#      'price': {'original': '24,95\xa0€',
#       'promotional': '7,50\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
# ...
#     {'key': 'WF5', 'label': 'WE Fashion', 'is_family': False},
#     {'key': 'WHA', 'label': 'Wheat', 'is_family': False},
#     {'key': 'WH9', 'label': 'White Stuff', 'is_family': False},
#     {'key': 'WO8', 'label': 'Woden', 'is_family': False},
#     {'key': 'XT1', 'label': 'XTI', 'is_family': False},
#     {'key': 'Y02', 'label': 'Young Versace', 'is_family': False},
#     {'key': 'Z21', 'label': 'Zadig & Voltaire', 'is_family': False},
#     {'key': 'ZAF',
#      'label': 'Zalando Essentials Kids',
#      'family_id': 'ZAES',
#      'is_family': False},
#     {'key': 'ZI7', 'label': 'Zip and Zoe', 'is_family': False},
#     {'key': 'IG2', 'label': ' IGOR ', 'is_family': False},
#     {'key': 'PO9', 'label': '3 Pommes', 'is_family': False}],
#    'family_key': 'brand_families'},
#   {'key': 'genders',
#    'label': 'Sexe',
#    'url_key': 'gender',
#    'kind': 'values',
#    'values': [{'key': 'FEMALE', 'label': 'Fille'},
#     {'key': 'MALE', 'label': 'Garçon'}]},
#   {'key': 'age_groups',
#    'label': 'Âge',
#    'url_key': 'gender',
#    'kind': 'values',
#    'values': [{'key': 'BABIES', 'label': 'Bébé'},
#     {'key': 'KIDS', 'label': 'Enfant'},
#     {'key': 'TEEN', 'label': 'Ado'}]},
#   {'key': 'prices',
#    'label': 'Prix',
#    'url_key': 'price',
#    'kind': 'range',
#    'range': {'min': 2.39,
#     'max': 396,
#     'unit': {'symbol': '€', 'position': 'suffix'}}},
#   {'key': 'colors',
#    'label': 'Couleur',
#    'url_key': 'color',
#    'kind': 'values',
#    'values': [{'key': 'BLACK', 'label': 'noir'},
#     {'key': 'BROWN', 'label': 'marron'},
#     {'key': 'BEIGE', 'label': 'beige'},
#     {'key': 'GRAY', 'label': 'gris'},
#     {'key': 'WHITE', 'label': 'blanc'},
#     {'key': 'BLUE', 'label': 'bleu'},
#     {'key': 'PETROL', 'label': 'bleu pétrole'},
#     {'key': 'TURQUOISE', 'label': 'turquoise'},
#     {'key': 'GREEN', 'label': 'vert'},
#     {'key': 'OLIVE', 'label': 'vert olive'},
#     {'key': 'YELLOW', 'label': 'jaune'},
#     {'key': 'ORANGE', 'label': 'orange'},
#     {'key': 'RED', 'label': 'rouge'},
#     {'key': 'PINK', 'label': 'rose'},
#     {'key': 'PURPLE', 'label': 'violet'},
#     {'key': 'GOLD', 'label': 'doré'},
#     {'key': 'SILVER', 'label': 'argenté'},
#     {'key': 'MULTICOLORED', 'label': 'multicolore'}]},
#   {'key': 'occasions',
#    'label': 'Occasion',
#    'url_key': 'occasion',
#    'kind': 'values',
#    'values': [{'key': 'LOUNGE_WEAR', 'label': 'confort/maison'},
#     {'key': 'OCTOBER_FEST', 'label': 'festival de la bière'},
#     {'key': 'EVENING', 'label': 'festive'},
#     {'key': 'BRIDAL', 'label': 'Looks de mariée'},
#     {'key': 'PARTY', 'label': 'soirée'},
#     {'key': 'LEISURE', 'label': 'sortie/détente'}]},
#   {'key': 'patterns',
#    'label': 'Motif',
#    'url_key': 'pattern',
#    'kind': 'values',
#    'values': [{'key': 'CAMOUFLAGE', 'label': 'camouflage'},
#     {'key': 'STRIPED', 'label': 'carreaux'},
#     {'key': 'HERRING_BONE', 'label': 'chevrons'},
#     {'key': 'FLECKED', 'label': 'chiné'},
#     {'key': 'PLAIN', 'label': 'couleur unie'},
#     {'key': 'GRADIENT', 'label': 'dégradé'},
#     {'key': 'BURNOUT', 'label': 'dévoré'},
#     {'key': 'PINSTRIPE', 'label': 'fines rayures'},
#     {'key': 'POLKA_DOT', 'label': 'floral'},
#     {'key': 'PRINT', 'label': 'imprimé'},
#     {'key': 'ANIMAL_PRINT', 'label': 'imprimé animal'},
#     {'key': 'PHOTO_PRINT', 'label': 'imprimé photo'},
#     {'key': 'COLORED', 'label': 'multicolore'},
#     {'key': 'PAISLEY', 'label': 'Paisley/cachemire'},
#     {'key': 'CHECKERED', 'label': 'rayures'},
#     {'key': 'FLORAL', 'label': 'à pois'}]},
#   {'key': 'sales',
#    'label': 'Soldes',
#    'url_key': 'sale',
#    'kind': 'single_value',
#    'values': [{'key': 'SALE', 'label': 'Voir les Promos'}]},
#   {'key': 'seasons',
#    'label': 'Saison',
#    'url_key': 'season_name',
#    'kind': 'values',
#    'values': [{'key': 'SUMMER', 'label': 'Printemps/Été'},
#     {'key': 'WINTER', 'label': 'Automne/Hiver'}]},
#   {'key': 'upper_materials',
#    'label': 'Matière',
#    'url_key': 'upper_material',
#    'kind': 'values',
#    'values': [{'key': 'OTHER', 'label': 'Autres matières'},
#     {'key': 'CASHMERE', 'label': 'Cachemire'},
#     {'key': 'CAOUTCHOUC', 'label': 'Caoutchouc'},
#     {'key': 'COTTON', 'label': 'Coton'},
#     {'key': 'CROCHETED', 'label': 'Crocheté'},
#     {'key': 'LEATHER', 'label': 'Cuir'},
#     {'key': 'CORD', 'label': 'Côtelé'},
#     {'key': 'DENIM', 'label': 'Denim'},
#     {'key': 'LACE', 'label': 'Dentelle'},
#     {'key': 'FELT', 'label': 'Feutre'},
#     {'key': 'HARDSHELL', 'label': 'Hardshell'},
#     {'key': 'IMITATION_LEATHER', 'label': 'Imitation cuir'},
#     {'key': 'JERSEY', 'label': 'Jersey'},
#     {'key': 'WOOL', 'label': 'Laine'},
#     {'key': 'LINEN', 'label': 'Lin'},
#     {'key': 'MESH', 'label': 'Mesh'},
#     {'key': 'MOHAIR', 'label': 'Mohair'},
#     {'key': 'FLEECE', 'label': 'Polaire'},
#     {'key': 'POLYESTER', 'label': 'Polyester'},
#     {'key': 'SATIN', 'label': 'Satin'},
#     {'key': 'SOFTSHELL', 'label': 'Softshell'},
#     {'key': 'SILK', 'label': 'Soie'},
#     {'key': 'RIB', 'label': 'Strié'},
#     {'key': 'SWEAT', 'label': 'Sweat'},
#     {'key': 'SYNTHETIC', 'label': 'Synthétique'},
#     {'key': 'TEXTILE', 'label': 'Textile'},
#     {'key': 'BRAIDED', 'label': 'tressé'},
#     {'key': 'VISCOSE', 'label': 'Viscose'}]},
#   {'key': 'trouser_rises',
#    'label': 'Type de taille',
#    'url_key': 'trouser_rise',
#    'kind': 'values',
#    'values': [{'key': 'LOW', 'label': 'basse'},
#     {'key': 'MEDIUM', 'label': 'normale'},
#     {'key': 'HIGH', 'label': 'haute'}]},
#   {'key': 'discounts',
#    'label': 'Réduction',
#    'url_key': 'discount',
#    'kind': 'values',
#    'values': [{'key': 'DISCOUNT0', 'label': 'jusqu’à -20 %'},
#     {'key': 'DISCOUNT1', 'label': '-20 %'},
#     {'key': 'DISCOUNT2', 'label': '-30 %'},
#     {'key': 'DISCOUNT3', 'label': '-40 %'},
#     {'key': 'DISCOUNT4', 'label': '-50 %'},
#     {'key': 'DISCOUNT5', 'label': '-60 % et plus'}]},
#   {'key': 'campaigns',
#    'label': 'Campaigns',
#    'url_key': 'camp',
#    'kind': 'single_value',
#    'values': [{'key': 'fr_ss19_eoss_fs_wave_3_2019_26', 'label': '-15% EXTRA'},
#     {'key': 'mu_sneaker_releases', 'label': 'Hot Sneaker Drops'}]},
#   {'key': 'fr_delivery_24h',
#    'label': 'Livraison 24H',
#    'url_key': 'livraison-24h',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Livraison 24H'}]},
#   {'key': 'sustainable',
#    'label': 'Éco-responsable',
#    'url_key': 'sustainable',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Éco-responsable'}]},
#   {'key': 'shipped_by_zalando',
#    'label': 'Expédié par Zalando',
#    'url_key': 'shipped_by_zalando',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Expédié par Zalando'}]}],
#  'total_article_count': 20299,
#  'plusStatus': 'unknown',
#  'categoryTree': [{'label': 'Promotions',
#    'id': '9574',
#    'url_key': 'promo-enfant',
#    'has_skus': True,
#    'selected': True,
#    'has_children': True,
#    'full_url': '/promo-enfant/',
#    'children': [{'label': 'Vêtements',
#      'id': '9579',
#      'url_key': 'promo-mode-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-mode-enfant/',
#      'children': [],
#      'article_count': 14845},
#     {'label': 'Chaussures',
#      'id': '9575',
#      'url_key': 'promo-chaussures-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-chaussures-enfant/',
#      'children': [],
#      'article_count': 4414},
#     {'label': 'Sport',
#      'id': '14007',
#      'url_key': 'promo-sport-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-sport-enfant/',
#      'children': [],
#      'article_count': 1966},
#     {'label': 'Sacs et accessoires',
#      'id': '9609',
#      'url_key': 'promo-accessoires-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-accessoires-enfant/',
#      'children': [],
#      'article_count': 768},
#     {'label': 'Luxe',
#      'id': '148690440',
#      'url_key': 'promo-luxe-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-luxe-enfant/',
#      'children': [],
#      'article_count': 2727}],
#    'article_count': 20299}],
#  'sortingKeys': [{'type': 'popularity', 'dir': 'desc', 'label': 'Préférés'},
#   {'type': 'activation_date', 'dir': 'desc', 'label': 'Nouveautés'},
#   {'type': 'price_asc', 'dir': 'asc', 'label': 'Prix croissant'},
#   {'type': 'price_desc', 'dir': 'desc', 'label': 'Prix décroissant'},
#   {'type': 'sale', 'dir': 'desc', 'label': 'Soldes'}],
#  'breadcrumbs': [{'items': [{'label': 'Enfant',
#      'url_key': 'enfant',
#      'full_url': '/enfant/'},
#     {'label': 'Promotions',
#      'url_key': 'promo-enfant',
#      'full_url': '/promo-enfant/'}]}],
#  'querySemantics': {'positive_filters': [{'key': 'categories',
#     'url_key': 'category',
#     'kind': 'values',
#     'values': [{'key': 'promo-enfant',
#       'url_key': 'promo-enfant',
#       'label': 'Promotions',
#       'seo_label': 'Promotions enfant',
#       'reset_url': '/',
#       'id': '9574'}]}],
#   'negative_filters': [],
#   'reset_query_url': '/promo-enfant/',
#   'reset_url': '/promo-enfant/',
#   'app_url': '?urlKey=promo-enfant&order=sale&appdomainId=11'},
#  'articlesToShow': 84,
#  'octopusTests': [],
#  'locale': 'fr-FR',
#  'isLoggedIn': False,
#  'notification': None,
#  'resetFilters': {'categories': [{'key': 'promo-enfant',
#     'url_key': 'promo-enfant',
#     'label': 'Promotions',
#     'seo_label': 'Promotions enfant',
#     'reset_url': '/',
#     'id': '9574'}]},
#  'selectedFilters': {'categories': ['promo-enfant']},
#  'ssrArticleCount': 32,
#  'feedbackId': '5c112594708a306b9e611805',
#  'variants': {'fullWidthCatalog': False,
#   'premiumCatalog': False,
#   'myBrandsFilter': True,
#   'outwardTeaserCard': False,
#   'hideCategories': False,
#   'mobileLightFilters': False},
#  'contentPositions': {'in-cat-carousel': 9,
#   'in-cat-carousel-mobile': 6,
#   'in-cat-carousel-fullwidth': 8,
#   'in-cat-teaser': 9,
#   'upper-in-cat-teaser': 5,
#   'entry-point-teasers': [7, 14, 20, 26],
#   'in-grid-filter': 4,
#   'size-dialog': 12,
#   'search-dialog': [9, 19],
#   'search-dialog-mobile': [8, 15],
#   'search-dialog-fullwidth': [12, 25],
#   'sneaker-carousel': [12],
#   'outfits': [5, 14, 23],
#   'outfits-mobile': [5, 11, 17, 23],
#   'outfits-fullwidth': [7, 19, 31, 43]},
#  'prideEnabled': True,
#  'seoText': None,
#  'teaser': {'content': {'creative_format': 'TEASER',
#    'brand': {'name': 'non-fashion brand', 'code': '-1'},
#    'pixels': ['https://creativefactory.zalando.fr/impressions/8b8a126f-277f-42f5-9e40-674ee4a79c5c/df749889-de0a-45a6-a26c-48586571ee99/creative.png?slotId=21672e65-4b93-4cd0-9943-404c19eece9a&creativeId=c683fdc5-25b9-4890-931b-589475968e0f&timeUnit=null&timeUnitCount=null&uuid=7855e155-a49b-43c5-9c77-3420d4dbe114&bid=null&requestId=cb21b69d-befc-4978-9cdc-339a16186a41&s=BE6A3BF0885A0E91D756EC6C53891131'],
#    'images': [{'aspect_ratio': '75:64',
#      'max_screen_size': 600,
#      'image_url': 'https://mosaic03.ztat.net/crt/creative-content/94a9c57f-374d-404b-bcbe-5fa6c68e52cc.jpg',
#      'image_width': 750},
#     {'aspect_ratio': '16:3',
#      'max_screen_size': 1200,
#      'image_url': 'https://mosaic03.ztat.net/crt/creative-content/bd04d164-3e8f-4d0d-bdc1-1608735702ec.jpg',
#      'image_width': 3200}],
#    'creative_id': 'c683fdc5-25b9-4890-931b-589475968e0f',
#    'campaign_id': '8b8a126f-277f-42f5-9e40-674ee4a79c5c',
#    'campaign_name': 'TCT FR SS19 EOSS FS Wave 3 Kids_FR_FR_CHILD_July_15_16_CatAd_C_000000',
#    'text_fields': {'cta': "J'en profite !",
#     'legal_claim': '*Offre valable du 15/07/2019 au 16/07/2019 jusqu\'à 23h59 sur les articles de la sélection "-15% EXTRA", pour un minimum d\'achat de 60€',
#     'voucher_code': 'SOLEIL19',
#     'sales_template': 'Voucher',
#     'title': 'Encore plus de styles',
#     'type': 'sales',
#     'byline': "SOLDES JUSQU'À -70% ET -15% EXTRA*",
#     'voucher_label': 'Code :'},
#    'tracking_events': {'impression': {'type': 'advertising-event',
#      'advertising-category': 'category',
#      'advertising-action': 'teaser impression',
#      'advertising-parameter': {'channel_name': 'CF',
#       'campaign_name': 'TCT FR SS19 EOSS FS Wave 3 Kids_FR_FR_CHILD_July_15_16_CatAd_C_000000',
#       'brand_code': '-1',
#       'billing_method': 'CPV',
#       'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#       'flow_id': 'BXC7E3QhATBv2Xrd',
#       'price': 0.011686516042128637,
#       'shop_slot_id': 'catalog',
#       'campaign_source_id': 'undefined',
#       'request_id': 'cb21b69d-befc-4978-9cdc-339a16186a41',
#       'campaign_id': '8b8a126f-277f-42f5-9e40-674ee4a79c5c',
#       'creative_id': 'c683fdc5-25b9-4890-931b-589475968e0f'}},
#     'view': {'type': 'teaser view',
#      'category': 'category',
#      'label': 'catalog.teaser',
#      'id': 'c683fdc5-25b9-4890-931b-589475968e0f',
#      'name': 'Encore plus de styles',
#      'parameters': {'dimension172': {'channel_name': 'CF',
#        'campaign_name': 'TCT FR SS19 EOSS FS Wave 3 Kids_FR_FR_CHILD_July_15_16_CatAd_C_000000',
#        'brand_code': '-1',
#        'billing_method': 'CPV',
#        'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#        'flow_id': 'BXC7E3QhATBv2Xrd',
#        'price': 0.011686516042128637,
#        'shop_slot_id': 'catalog',
#        'campaign_source_id': 'undefined',
#        'request_id': 'cb21b69d-befc-4978-9cdc-339a16186a41',
#        'campaign_id': '8b8a126f-277f-42f5-9e40-674ee4a79c5c',
#        'creative_id': 'c683fdc5-25b9-4890-931b-589475968e0f'}}},
#     'click': {'type': 'teaser click',
#      'category': 'category',
#      'label': 'catalog.teaser',
#      'id': 'c683fdc5-25b9-4890-931b-589475968e0f',
#      'name': 'Encore plus de styles',
#      'parameters': {'dimension172': {'channel_name': 'CF',
#        'campaign_name': 'TCT FR SS19 EOSS FS Wave 3 Kids_FR_FR_CHILD_July_15_16_CatAd_C_000000',
#        'brand_code': '-1',
#        'billing_method': 'CPV',
#        'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#        'flow_id': 'BXC7E3QhATBv2Xrd',
#        'price': 0.011686516042128637,
#        'shop_slot_id': 'catalog',
#        'campaign_source_id': 'undefined',
#        'request_id': 'cb21b69d-befc-4978-9cdc-339a16186a41',
#        'campaign_id': '8b8a126f-277f-42f5-9e40-674ee4a79c5c',
#        'creative_id': 'c683fdc5-25b9-4890-931b-589475968e0f'}}}},
#    'view_pixels': ['https://creativefactory.zalando.fr/views/8b8a126f-277f-42f5-9e40-674ee4a79c5c/df749889-de0a-45a6-a26c-48586571ee99/creative.png?slotId=21672e65-4b93-4cd0-9943-404c19eece9a&creativeId=c683fdc5-25b9-4890-931b-589475968e0f&timeUnit=null&timeUnitCount=null&uuid=cba7f2b4-c9f1-4426-824f-fe9d113663ef&bid=12&requestId=cb21b69d-befc-4978-9cdc-339a16186a41&s=F9086A9A1A88ACBCC84AC56517C2EA5A'],
#    'tracking_data': {'explicit_tracking_params': {'flow_id': 'BXC7E3QhATBv2Xrd',
#      'entity_id': None,
#      'shop_slot_id': 'catalog',
#      'brand_code': '-1',
#      'campaign_source_id': None,
#      'campaign_id': '8b8a126f-277f-42f5-9e40-674ee4a79c5c',
#      'creative_id': 'c683fdc5-25b9-4890-931b-589475968e0f',
#      'campaign_name': 'TCT FR SS19 EOSS FS Wave 3 Kids_FR_FR_CHILD_July_15_16_CatAd_C_000000',
#      'target_entity_id': None},
#     'cf_tracking_params': {'channel_name': 'CF',
#      'campaign_name': 'TCT FR SS19 EOSS FS Wave 3 Kids_FR_FR_CHILD_July_15_16_CatAd_C_000000',
#      'brand_code': '-1',
#      'billing_method': 'CPV',
#      'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#      'flow_id': 'BXC7E3QhATBv2Xrd',
#      'price': 0.011686516042128637,
#      'shop_slot_id': 'catalog',
#      'campaign_source_id': 'undefined',
#      'request_id': 'cb21b69d-befc-4978-9cdc-339a16186a41',
#      'campaign_id': '8b8a126f-277f-42f5-9e40-674ee4a79c5c',
#      'creative_id': 'c683fdc5-25b9-4890-931b-589475968e0f'}},
#    'click_url': 'https://www.zalando.fr/enfant/?camp=fr_ss19_eoss_fs_wave_3_2019_26'},
#   'channel_name': 'CF',
#   'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a'},
#  'inCatalogTeaser': None,
#  'entryPointTeasers': None,
#  'upperInCatTeaser': None,
#  'collection': None,
#  'carouselTeaser': None,
#  'wishlist': None,
#  'pills': None,
#  'styleYourKicks': None,
#  'sizeOnboardingDialog': None}

# %%
flattened_data = json_normalize(results)

flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1
# Out:
#    amount               brand_name  \
# 0     NaN                    Guess
# 1     NaN                   Esprit
# 2     NaN      Jack & Jones Junior
# 3     NaN                  Name it
# 4     NaN                      GAP
# 5     NaN               Quiksilver
# 6     NaN                 Benetton
# 7     NaN                 Benetton
# 8     NaN                 Staccato
# 9     NaN                 Benetton
# 10    NaN                 Benetton
# 11    NaN                 Benetton
# 12    NaN         Nike Performance
# 13    NaN                  Lacoste
# 14    NaN          Nike Sportswear
# 15    NaN         Nike Performance
# 16    NaN                   Esprit
# 17    NaN                Sunnylife
# 18    NaN                 Benetton
# 19    NaN         Nike Performance
# 20    NaN              Blue Effect
# 21    NaN                   Re-Gen
# 22    NaN        Polo Ralph Lauren
# 23    NaN                     LMTD
# 24    NaN         Nike Performance
# 25    NaN                 3 Pommes
# 26    NaN                      OVS
# 27    NaN       adidas Performance
# 28    NaN                 Benetton
# 29    NaN               Pepe Jeans
# ..    ...                      ...
# 54    NaN  Zalando Essentials Kids
# 55    NaN                   Re-Gen
# 56    NaN                   Friboo
# 57    NaN        Polo Ralph Lauren
# 58    NaN                  Lacoste
# 59    NaN                   Friboo
# 60    NaN             Sonia Rykiel
# 61    NaN         Nike Performance
# 62    NaN                   Friboo
# 63    NaN                 Benetton
# 64    NaN                 Benetton
# 65    NaN                      GAP
# 66    NaN                 Benetton
# 67    NaN                  Name it
# 68    NaN                 Converse
# 69    NaN                      OVS
# 70    NaN      Abercrombie & Fitch
# 71    NaN                 Champion
# 72    NaN             Retour Jeans
# 73    NaN               TOM TAILOR
# 74    NaN               Mini Molly
# 75    NaN                   Esprit
# 76    NaN                     LMTD
# 77    NaN                      GAP
# 78    NaN                   Esprit
# 79    NaN      Abercrombie & Fitch
# 80    NaN                     Puma
# 81    NaN                     LMTD
# 82    NaN         Nike Performance
# 83    NaN                  Nike SB
#
#                                       family_articles  \
# 0   [{'sku': 'GU153I00G-Q11', 'url_key': 'guess-sm...
# 1   [{'sku': 'ES124A08B-K11', 'url_key': 'esprit-p...
# 2   [{'sku': 'JAN24G00M-A11', 'url_key': 'jackandj...
# 3   [{'sku': 'NA823F0VH-K11', 'url_key': 'name-it-...
# 4   [{'sku': 'GP024G0FG-E11', 'url_key': 'gap-marc...
# 5   [{'sku': 'QU124L01V-K11', 'url_key': 'quiksilv...
# 6   [{'sku': '4BE23F082-A11', 'url_key': 'benetton...
# 7   [{'sku': '4BE24I023-K15', 'url_key': 'benetton...
# 8   [{'sku': 'STF24C00P-T11', 'url_key': 'staccato...
# 9   [{'sku': '4BE23F083-I11', 'url_key': 'benetton...
# 10  [{'sku': '4BE23G0DU-K11', 'url_key': 'benetton...
# 11  [{'sku': '4BE23G0DU-A11', 'url_key': 'benetton...
# 12  [{'sku': 'N1243G09Y-G11', 'url_key': 'nike-per...
# 13  [{'sku': 'LA253M003-K11', 'url_key': 'lacoste-...
# 14  [{'sku': 'NI114D0A9-C11', 'url_key': 'nike-spo...
# 15  [{'sku': 'N1243K0B0-Q11', 'url_key': 'nike-per...
# 16  [{'sku': 'ES123A099-G11', 'url_key': 'esprit-p...
# 17  [{'sku': 'SUF53I000-E11', 'url_key': 'sunnylif...
# 18  [{'sku': '4BE24A05P-H11', 'url_key': 'benetton...
# 19  [{'sku': 'N1243G09X-Q11', 'url_key': 'nike-per...
# 20  [{'sku': 'BE024B00K-K11', 'url_key': 'blue-eff...
# 21  [{'sku': 'RG524K00Q-C11', 'url_key': 're-gen-t...
# 22  [{'sku': 'PO253M00N-K11', 'url_key': 'polo-ral...
# 23  [{'sku': 'L0423J00N-B11', 'url_key': 'lmtd-nlf...
# 24  [{'sku': 'N1243E0KJ-K12', 'url_key': 'nike-per...
# 25  [{'sku': 'PO923F02X-A12', 'url_key': '3-pommes...
# 26  [{'sku': 'OV024G0AC-C11', 'url_key': 'ovs-stri...
# 27  [{'sku': 'AD543G08G-C11', 'url_key': 'adidas-p...
# 28  [{'sku': '4BE23L04D-K11', 'url_key': 'benetton...
# 29  [{'sku': 'PE113D00C-A11', 'url_key': 'pepe-jea...
# ..                                                ...
# 54  [{'sku': 'ZAF26B002-K11', 'url_key': 'zalando-...
# 55  [{'sku': 'RG524G02G-Q11', 'url_key': 're-gen-t...
# 56  [{'sku': 'F5723K022-E11', 'url_key': 'friboo-s...
# 57  [{'sku': 'PO224D033-A11', 'url_key': 'polo-ral...
# 58  [{'sku': 'LA224K00X-K11', 'url_key': 'lacoste-...
# 59  [{'sku': 'F5723G04A-I11', 'url_key': 'friboo-g...
# 60  [{'sku': 'SY953I001-B11', 'url_key': 'sonia-ry...
# 61  [{'sku': 'N1243D11U-Q11', 'url_key': 'nike-per...
# 62  [{'sku': 'F5723K024-I11', 'url_key': 'friboo-n...
# 63  [{'sku': '4BE24B03K-N11', 'url_key': 'benetton...
# 64  [{'sku': '4BE24G0CE-K11', 'url_key': 'benetton...
# 65  [{'sku': 'GP023G0C1-C11', 'url_key': 'gap-girl...
# 66  [{'sku': '4BE24C02Y-G11', 'url_key': 'benetton...
# 67  [{'sku': 'NA823L0BT-K11', 'url_key': 'name-it-...
# 68  [{'sku': 'CO413A01B-A11', 'url_key': 'converse...
# 69  [{'sku': 'OV023F03F-G11', 'url_key': 'ovs-stri...
# 70  [{'sku': 'A0F23G039-K11', 'url_key': 'abercrom...
# 71  [{'sku': 'C7643G02Q-H11', 'url_key': 'champion...
# 72  [{'sku': 'RJ223A01E-K11', 'url_key': 'retour-j...
# 73  [{'sku': 'TO223G0F5-J11', 'url_key': 'tom-tail...
# 74  [{'sku': 'MM723C006-K11', 'url_key': 'mini-mol...
# 75  [{'sku': 'ES124G0HK-A11', 'url_key': 'esprit-t...
# 76  [{'sku': 'NA823K0E0-C11', 'url_key': 'name-it-...
# 77  [{'sku': 'GP024G0EF-G11', 'url_key': 'gap-todd...
# 78  [{'sku': 'ES124G0IA-M11', 'url_key': 'esprit-t...
# 79  [{'sku': 'A0F23K00Z-G11', 'url_key': 'abercrom...
# 80  [{'sku': 'PU116F005-G11', 'url_key': 'puma-ses...
# 81  [{'sku': 'L0424K00Y-K11', 'url_key': 'lmtd-nlm...
# 82  [{'sku': 'N1243G022-C11', 'url_key': 'nike-per...
# 83  [{'sku': 'NS414D005-K23', 'url_key': 'nike-sb-...
#
#                                                 flags  is_premium  \
# 0   [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 1   [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 2   [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 3   [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 4   [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 5   [{'key': 'discountRate', 'value': '-50%', 'tra...       False
# 6   [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 7   [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 8   [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 9   [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 10  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 12  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 13  [{'key': 'campaign', 'value': '-15% EXTRA', 't...        True
# 14  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 15  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 16  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 17  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 18  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 19  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 20  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 21  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 22  [{'key': 'campaign', 'value': '-15% EXTRA', 't...        True
# 23  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 24  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 25  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 26  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 27  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 28  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 29  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# ..                                                ...         ...
# 54  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 55  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 56  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 57  [{'key': 'campaign', 'value': '-15% EXTRA', 't...        True
# 58  [{'key': 'campaign', 'value': '-15% EXTRA', 't...        True
# 59  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 60  [{'key': 'campaign', 'value': '-15% EXTRA', 't...        True
# 61  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 62  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 63  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 64  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 65  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 66  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 67  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 68  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 69  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 70  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 71  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 72  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 73  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 74  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 75  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 76  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 77  [{'key': 'discountRate', 'value': '-70%', 'tra...       False
# 78  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 79  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 80  [{'key': 'discountRate', 'value': 'Jusqu’à -56...       False
# 81  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 82  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 83  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
#
#                                                 media  \
# 0   [{'path': 'GU/15/3I/00/GQ/11/GU153I00G-Q11@3.j...
# 1   [{'path': 'ES/12/4A/08/BK/11/ES124A08B-K11@2.j...
# 2   [{'path': 'JA/N2/4G/00/MA/11/JAN24G00M-A11@5.j...
# 3   [{'path': 'NA/82/3F/0V/HK/11/NA823F0VH-K11@2.j...
# 4   [{'path': 'GP/02/4G/0F/GE/11/GP024G0FG-E11@7.j...
# 5   [{'path': 'QU/12/4L/01/VK/11/QU124L01V-K11@11....
# 6   [{'path': '4B/E2/3F/08/2A/11/4BE23F082-A11@2.j...
# 7   [{'path': '4B/E2/4I/02/3K/15/4BE24I023-K15@2.j...
# 8   [{'path': 'ST/F2/4C/00/PT/11/STF24C00P-T11@11....
# 9   [{'path': '4B/E2/3F/08/3I/11/4BE23F083-I11@2.j...
# 10  [{'path': '4B/E2/3G/0D/UK/11/4BE23G0DU-K11@4.j...
# 11  [{'path': '4B/E2/3G/0D/UA/11/4BE23G0DU-A11@2.j...
# 12  [{'path': 'N1/24/3G/09/YG/11/N1243G09Y-G11@8.j...
# 13  [{'path': 'LA/25/3M/00/3K/11/LA253M003-K11@5.j...
# 14  [{'path': 'NI/11/4D/0A/9C/11/NI114D0A9-C11@3.j...
# 15  [{'path': 'N1/24/3K/0B/0Q/11/N1243K0B0-Q11@6.j...
# 16  [{'path': 'ES/12/3A/09/9G/11/ES123A099-G11@5.j...
# 17  [{'path': 'SU/F5/3I/00/0E/11/SUF53I000-E11@3.j...
# 18  [{'path': '4B/E2/4A/05/PH/11/4BE24A05P-H11@8.j...
# 19  [{'path': 'N1/24/3G/09/XQ/11/N1243G09X-Q11@4.j...
# 20  [{'path': 'BE/02/4B/00/KK/11/BE024B00K-K11@2.j...
# 21  [{'path': 'RG/52/4K/00/QC/11/RG524K00Q-C11@8.j...
# 22  [{'path': 'PO/25/3M/00/NK/11/PO253M00N-K11@7.j...
# 23  [{'path': 'L0/42/3J/00/NB/11/L0423J00N-B11@9.j...
# 24  [{'path': 'N1/24/3E/0K/JK/12/N1243E0KJ-K12@7.j...
# 25  [{'path': 'PO/92/3F/02/XA/12/PO923F02X-A12@7.j...
# 26  [{'path': 'OV/02/4G/0A/CC/11/OV024G0AC-C11@2.j...
# 27  [{'path': 'AD/54/3G/08/GC/11/AD543G08G-C11@8.j...
# 28  [{'path': '4B/E2/3L/04/DK/11/4BE23L04D-K11@4.j...
# 29  [{'path': 'PE/11/3D/00/CA/11/PE113D00C-A11@8.j...
# ..                                                ...
# 54  [{'path': 'ZA/F2/6B/00/2K/11/ZAF26B002-K11@4.j...
# 55  [{'path': 'RG/52/4G/02/GQ/11/RG524G02G-Q11@8.j...
# 56  [{'path': 'F5/72/3K/02/2E/11/F5723K022-E11@4.j...
# 57  [{'path': 'PO/22/4D/03/3A/11/PO224D033-A11@9.j...
# 58  [{'path': 'LA/22/4K/00/XK/11/LA224K00X-K11@12....
# 59  [{'path': 'F5/72/3G/04/AI/11/F5723G04A-I11@11....
# 60  [{'path': 'SY/95/3I/00/1B/11/SY953I001-B11@8.j...
# 61  [{'path': 'N1/24/3D/11/UQ/11/N1243D11U-Q11@12....
# 62  [{'path': 'F5/72/3K/02/4I/11/F5723K024-I11@11....
# 63  [{'path': '4B/E2/4B/03/KN/11/4BE24B03K-N11@2.j...
# 64  [{'path': '4B/E2/4G/0C/EK/11/4BE24G0CE-K11@12....
# 65  [{'path': 'GP/02/3G/0C/1C/11/GP023G0C1-C11@6.j...
# 66  [{'path': '4B/E2/4C/02/YG/11/4BE24C02Y-G11@7.j...
# 67  [{'path': 'NA/82/3L/0B/TK/11/NA823L0BT-K11@10....
# 68  [{'path': 'CO/41/3A/01/BA/11/CO413A01B-A11@12....
# 69  [{'path': 'OV/02/3F/03/FG/11/OV023F03F-G11@2.1...
# 70  [{'path': 'A0/F2/3G/03/9K/11/A0F23G039-K11@2.j...
# 71  [{'path': 'C7/64/3G/02/QH/11/C7643G02Q-H11@10....
# 72  [{'path': 'RJ/22/3A/01/EK/11/RJ223A01E-K11@4.j...
# 73  [{'path': 'TO/22/3G/0F/5J/11/TO223G0F5-J11@6.j...
# 74  [{'path': 'MM/72/3C/00/6K/11/MM723C006-K11@7.j...
# 75  [{'path': 'ES/12/4G/0H/KA/11/ES124G0HK-A11@12....
# 76  [{'path': 'NA/82/3K/0E/0C/11/NA823K0E0-C11@6.1...
# 77  [{'path': 'GP/02/4G/0E/FG/11/GP024G0EF-G11@7.j...
# 78  [{'path': 'ES/12/4G/0I/AM/11/ES124G0IA-M11@10....
# 79  [{'path': 'A0/F2/3K/00/ZG/11/A0F23K00Z-G11@6.j...
# 80  [{'path': 'PU/11/6F/00/5G/11/PU116F005-G11@3.j...
# 81  [{'path': 'L0/42/4K/00/YK/11/L0424K00Y-K11@2.j...
# 82  [{'path': 'N1/24/3G/02/2C/11/N1243G022-C11@8.j...
# 83  [{'path': 'NS/41/4D/00/5K/23/NS414D005-K23@3.j...
#
#                                                  name  \
# 0              SMALL BACKPACK - Sac à dos - jet black
# 1                     PANTS - Jean slim - medium wash
# 2   JORHOTEL TEE CREW NECK JUNIOR - T-shirt imprim...
# 3     DRESS CAMPMINI - Robe en jersey - dark sapphire
# 4                     T-shirt imprimé - canary yellow
# 5                                Veste d'hiver - navy
# 6                DRESS - Robe en jersey - white/black
# 7                                      Chemise - blue
# 8   BERMUDAS 2 PACK - Short - indigo structure/sun...
# 9                      DRESS - Robe en jersey - lilac
# 10                           BASIC - Polo - dark blue
# 11                               BASIC - Polo - white
# 12  HOODIE - veste en sweat zippée - university re...
# 13                         BOY  - Chapeau - navy blue
# 14  MD RUNNER 2 - Baskets basses - atmosphere grey...
# 15  AIR MAX BODYSUIT BOOTIE SET - Survêtement - black
# 16                     PANTS - Jean slim - watermelon
# 17       GIRAFFE KIDS LUNCH BAG - Sac à main - yellow
# 18             TROUSERS BASIC - Jean slim - dark blue
# 19  veste en sweat zippée - black/sail/university ...
# 20         BOYS - Pantalon de survêtement - nachtblau
# 21                   TEENS  - Pullover - grey melange
# 22  APPAREL ACCESSORIES HAT BABY - Casquette - new...
# 23           NLFDAMIER O NECK - Sweatshirt - moonbeam
# 24  DRY ACADEMY PANT - Pantalon de survêtement - i...
# 25          DRESS MANCHES - Robe d'été - broken white
# 26                             STRIPES - Polo - righe
# 27   Sweat à capuche - medium grey heather/shock cyan
# 28           JACKET BASIC - Veste d'hiver - dark blue
# 29              BELLE HEARTH - Baskets basses - white
# ..                                                ...
# 54                  Pantalon de survêtement - peacoat
# 55                            T-shirt imprimé - black
# 56                        Sweatshirt - mineral yellow
# 57  STRIPE ONE PIECE - Combinaison - white/french ...
# 58  BOY  - Sweat à capuche - salvia/navy blue/silv...
# 59      GO FOR IT  - T-shirt imprimé - orchid bouquet
# 60                      COOKIE - Sac à main - vanille
# 61                DRY - T-shirt imprimé - black/white
# 62  NO RULES CROP HOODY - Sweat à capuche - purple...
# 63                     TROUSERS BASIC - Chino - khaki
# 64                             T-shirt imprimé - blue
# 65                GIRLS YOKE  - Blouse - grey heather
# 66                   BERMUDA BASIC - Short - dark red
# 67  NMFMELLO JACKET UNICORNSMINI - Veste mi-saison...
# 68  CHUCK TAYLOR FIRST STAR - Chaussons pour bébé ...
# 69  STRIPED DRESS GIRL - Robe en jersey - chinese red
# 70                        GRAPHIC - Sweatshirt - navy
# 71  AMERICAN CLASSICS HOODED  - Sweat à capuche - ...
# 72                  ZITA - Jeans Skinny - medium blue
# 73  PLACED PRINT - T-shirt à manches longues - sil...
# 74                     STAR GIRLS - Short - navy blue
# 75                            T-shirt imprimé - white
# 76                           Sweatshirt - sky captain
# 77               TODDLER BOY PATCH - Polo - new coral
# 78                       T-shirt imprimé - soft green
# 79          COLORBLOCK CREW - Sweatshirt - light pink
# 80  SESAME 50 - Chaussures premiers pas - cherry t...
# 81                 NLMRAMI - Sweatshirt - sky captain
# 82            Sweat à capuche - dk grey heather/white
# 83  STEFAN JANOSKI - Baskets basses - obsidian/lig...
#
#     price.has_different_original_prices  price.has_different_prices  \
# 0                                 False                       False
# 1                                 False                        True
# 2                                 False                       False
# 3                                 False                       False
# 4                                 False                       False
# 5                                 False                       False
# 6                                 False                       False
# 7                                 False                       False
# 8                                 False                       False
# 9                                 False                       False
# 10                                False                       False
# 11                                False                       False
# 12                                False                        True
# 13                                False                        True
# 14                                False                        True
# 15                                False                       False
# 16                                False                        True
# 17                                False                       False
# 18                                False                       False
# 19                                False                        True
# 20                                False                       False
# 21                                False                       False
# 22                                False                       False
# 23                                False                        True
# 24                                False                        True
# 25                                False                       False
# 26                                False                       False
# 27                                False                       False
# 28                                False                       False
# 29                                False                        True
# ..                                  ...                         ...
# 54                                False                       False
# 55                                False                       False
# 56                                False                        True
# 57                                False                       False
# 58                                False                        True
# 59                                False                        True
# 60                                False                       False
# 61                                False                        True
# 62                                False                        True
# 63                                False                       False
# 64                                False                       False
# 65                                False                       False
# 66                                False                       False
# 67                                False                       False
# 68                                False                       False
# 69                                False                       False
# 70                                False                       False
# 71                                False                       False
# 72                                False                       False
# 73                                False                       False
# 74                                False                       False
# 75                                False                       False
# 76                                False                       False
# 77                                False                       False
# 78                                False                       False
# 79                                False                       False
# 80                                False                        True
# 81                                False                       False
# 82                                False                       False
# 83                                False                       False
#
#     price.has_different_promotional_prices  \
# 0                                    False
# 1                                     True
# 2                                    False
# 3                                    False
# 4                                    False
# 5                                    False
# 6                                    False
# 7                                    False
# 8                                    False
# 9                                    False
# 10                                   False
# 11                                   False
# 12                                    True
# 13                                    True
# 14                                    True
# 15                                   False
# 16                                    True
# 17                                   False
# 18                                   False
# 19                                    True
# 20                                   False
# 21                                   False
# 22                                   False
# 23                                    True
# 24                                    True
# 25                                   False
# 26                                   False
# 27                                   False
# 28                                   False
# 29                                    True
# ..                                     ...
# 54                                   False
# 55                                   False
# 56                                    True
# 57                                   False
# 58                                    True
# 59                                    True
# 60                                   False
# 61                                    True
# 62                                    True
# 63                                   False
# 64                                   False
# 65                                   False
# 66                                   False
# 67                                   False
# 68                                   False
# 69                                   False
# 70                                   False
# 71                                   False
# 72                                   False
# 73                                   False
# 74                                   False
# 75                                   False
# 76                                   False
# 77                                   False
# 78                                   False
# 79                                   False
# 80                                    True
# 81                                   False
# 82                                   False
# 83                                   False
#
#     price.has_discount_on_selected_sizes_only price.original  \
# 0                                       False        59,95 €
# 1                                       False        35,99 €
# 2                                       False        12,95 €
# 3                                       False        12,95 €
# 4                                       False        12,95 €
# 5                                       False        75,99 €
# 6                                       False        19,95 €
# 7                                       False        19,95 €
# 8                                       False        17,95 €
# 9                                       False        19,95 €
# 10                                      False        17,95 €
# 11                                      False        17,95 €
# 12                                      False        54,95 €
# 13                                      False        40,00 €
# 14                                      False        44,95 €
# 15                                      False        19,95 €
# 16                                      False        25,95 €
# 17                                      False        24,95 €
# 18                                      False        25,95 €
# 19                                      False        54,95 €
# 20                                      False        39,99 €
# 21                                      False        29,95 €
# 22                                      False        24,95 €
# 23                                      False        28,95 €
# 24                                      False        39,95 €
# 25                                      False        49,95 €
# 26                                      False        12,95 €
# 27                                      False        37,95 €
# 28                                      False        39,95 €
# 29                                      False        54,95 €
# ..                                        ...            ...
# 54                                      False        12,99 €
# 55                                      False        12,95 €
# 56                                      False        17,95 €
# 57                                      False        45,95 €
# 58                                      False        72,00 €
# 59                                      False        14,95 €
# 60                                      False        69,95 €
# 61                                      False        24,95 €
# 62                                      False        19,95 €
# 63                                      False        22,95 €
# 64                                      False         9,95 €
# 65                                      False        19,95 €
# 66                                      False        17,95 €
# 67                                      False        24,99 €
# 68                                      False        29,95 €
# 69                                      False        15,95 €
# 70                                      False        28,95 €
# 71                                      False        27,95 €
# 72                                      False        54,95 €
# 73                                      False        15,99 €
# 74                                      False        34,95 €
# 75                                      False        12,99 €
# 76                                      False        32,99 €
# 77                                      False        19,95 €
# 78                                      False        15,95 €
# 79                                      False        37,95 €
# 80                                      False        54,95 €
# 81                                      False        36,95 €
# 82                                      False        34,95 €
# 83                                      False        59,95 €
#
#    price.promotional product_group  \
# 0            36,00 €   accessoires
# 1            10,80 €      clothing
# 2             3,90 €      clothing
# 3             3,89 €      clothing
# 4             3,89 €      clothing
# 5            38,00 €      clothing
# 6             6,00 €      clothing
# 7             9,00 €      clothing
# 8             5,40 €      clothing
# 9             6,00 €      clothing
# 10            7,18 €      clothing
# 11            7,18 €      clothing
# 12           44,00 €      clothing
# 13           28,00 €   accessoires
# 14           31,46 €          shoe
# 15           12,95 €      clothing
# 16            7,80 €      clothing
# 17            7,50 €   accessoires
# 18           10,38 €      clothing
# 19           29,95 €      clothing
# 20           12,00 €      clothing
# 21            9,00 €      clothing
# 22           20,00 €   accessoires
# 23            8,70 €      clothing
# 24           14,00 €      clothing
# 25           14,95 €      clothing
# 26            4,53 €      clothing
# 27           15,00 €      clothing
# 28           23,95 €      clothing
# 29           27,48 €          shoe
# ..               ...           ...
# 54            6,50 €      clothing
# 55            5,18 €      clothing
# 56            9,87 €      clothing
# 57           25,45 €      clothing
# 58           50,00 €      clothing
# 59            4,49 €      clothing
# 60           24,45 €   accessoires
# 61           19,95 €      clothing
# 62           10,00 €      clothing
# 63           10,35 €      clothing
# 64            3,00 €      clothing
# 65            6,00 €      clothing
# 66            9,00 €      clothing
# 67           12,49 €      clothing
# 68           19,47 €          shoe
# 69            6,38 €      clothing
# 70            8,70 €      clothing
# 71           22,35 €      clothing
# 72           16,45 €      clothing
# 73            4,80 €      clothing
# 74           17,48 €      clothing
# 75            3,90 €      clothing
# 76            9,90 €      clothing
# 77            6,00 €      clothing
# 78            4,80 €      clothing
# 79           13,28 €      clothing
# 80           24,45 €          shoe
# 81           11,10 €      clothing
# 82           24,45 €      clothing
# 83           36,00 €          shoe
#
#                                                 sizes            sku  \
# 0                                          [One Size]  GU153I00G-Q11
# 1                        [2a, 3a, 4a, 5a, 6a, 7a, 8a]  ES124A08B-K11
# 2                            [8a, 10a, 12a, 14a, 16a]  JAN24G00M-A11
# 3       [5a, 6a, 7a, 8a, 9a, 10a, 11a, 12a, 13a, 14a]  NA823F0VH-K11
# 4                            [2a, 3a, 4a, 5a, 18-24m]  GP024G0FG-E11
# 5                                 [8a, 10a, 12a, 14a]  QU124L01V-K11
# 6                  [6-7a, 7-8a, 8-9a, 10-11a, 11-12a]  4BE23F082-A11
# 7   [3-4a, 4-5a, 6-7a, 7-8a, 8-9a, 10-11a, 11-12a,...  4BE24I023-K15
# 8                        [4-6m, 7-9m, 10-12m, 13-18m]  STF24C00P-T11
# 9   [3-4a, 4-5a, 6-7a, 7-8a, 8-9a, 10-11a, 11-12a,...  4BE23F083-I11
# 10  [3-4a, 4-5a, 6-7a, 7-8a, 8-9a, 10-11a, 11-12a,...  4BE23G0DU-K11
# 11  [3-4a, 4-5a, 6-7a, 7-8a, 8-9a, 10-11a, 11-12a,...  4BE23G0DU-A11
# 12              [6-8a, 8-10a, 10-12a, 12-13a, 13-15a]  N1243G09Y-G11
# 13                                     [2a/5a, 6a/9a]  LA253M003-K11
# 14       [28.5, 29.5, 30, 31.5, 32, 33, 33.5, 34, 35]  NI114D0A9-C11
# 15                                            [6-12m]  N1243K0B0-Q11
# 16                       [2a, 3a, 4a, 5a, 6a, 7a, 8a]  ES123A099-G11
# 17                                         [One Size]  SUF53I000-E11
# 18  [3-4a, 4-5a, 6-7a, 7-8a, 8-9a, 10-11a, 11-12a,...  4BE24A05P-H11
# 19              [6-8a, 8-10a, 10-12a, 12-13a, 13-15a]  N1243G09X-Q11
# 20                    [9-10a, 11-12a, 13-14a, 15-16a]  BE024B00K-K11
# 21                               [10a, 12a, 14a, 16a]  RG524K00Q-C11
# 22                                         [One Size]  PO253M00N-K11
# 23                         [11a-12a, 13a-14a, 9a-10a]  L0423J00N-B11
# 24                    [8-10a, 10-12a, 12-13a, 13-15a]  N1243E0KJ-K12
# 25      [2-3a, 3-4a, 4-5a, 5-6a, 7-8a, 9-10a, 11-12a]  PO923F02X-A12
# 26                   [12-18m, 18-24m, 24-30m, 30-36m]  OV024G0AC-C11
# 27              [7-8a, 9-10a, 11-12a, 13-14a, 15-16a]  AD543G08G-C11
# 28  [4-5a, 6-7a, 7-8a, 10-11a, 11-12a, 13-14a, 18-...  4BE23L04D-K11
# 29                   [32, 33, 34, 35, 36, 37, 38, 39]  PE113D00C-A11
# ..                                                ...            ...
# 54  [122/128, 134/140, 146/152, 158/164, 170/176, ...  ZAF26B002-K11
# 55                                    [10a, 12a, 14a]  RG524G02G-Q11
# 56               [134/140, 146/152, 158/164, 170/176]  F5723K022-E11
# 57                                [3-6m, 6-9m, 9-12m]  PO224D033-A11
# 58            [2a, 3y, 4a, 5a, 6a, 8a, 10a, 12a, 14a]  LA224K00X-K11
# 59       [110/116, 122/128, 134/140, 146/152, 98/104]  F5723G04A-I11
# 60                                         [One Size]  SY953I001-B11
# 61              [6-8a, 8-10a, 10-12a, 12-13a, 13-15a]  N1243D11U-Q11
# 62      [110/116, 134/140, 146/152, 158/164, 170/176]  F5723K024-I11
# 63  [3-4a, 4-5a, 6-7a, 7-8a, 8-9a, 10-11a, 11-12a,...  4BE24B03K-N11
# 64          [1-3m, 3-6m, 6-9m, 9-12m, 12-18m, 18-24m]  4BE24G0CE-K11
# 65               [6-7a, 8-9a, 10-11a, 12-13a, 14-16a]  GP023G0C1-C11
# 66  [4-5a, 6-7a, 8-9a, 10-11a, 11-12a, 13-14a, 18-...  4BE24C02Y-G11
# 67                               [2a, 3a, 4a, 6a, 7a]  NA823L0BT-K11
# 68                                   [17, 18, 19, 20]  CO413A01B-A11
# 69                     [4-5a, 5-6a, 6-7a, 7-8a, 8-9a]  OV023F03F-G11
# 70  [11a/12a, 13a/14a, 15a/16a, 5a/6a, 7a/8a, 9a/10a]  A0F23G039-K11
# 71               [5-6a, 7-8a, 11-12a, 13-14a, 15-16a]  C7643G02Q-H11
# 72                           [8a, 10a, 12a, 14a, 16a]  RJ223A01E-K11
# 73                       [9-10a, 11-12a, 13-14a, 15a]  TO223G0F5-J11
# 74           [10a/12a, 12a/14a, 4a/6a, 6a/8a, 8a/10a]  MM723C006-K11
# 75                              [4a/5a, 6a/7a, 8a/9a]  ES124G0HK-A11
# 76                    [9-10a, 11-12a, 13-14a, 15-16a]  NA823K0E0-C11
# 77                           [2a, 3a, 4a, 5a, 18-24m]  GP024G0EF-G11
# 78                                       [4a, 6a, 8a]  ES124G0IA-M11
# 79         [11a/12a, 13a/14a, 15a/16a, 7a/8a, 9a/10a]  A0F23K00Z-G11
# 80                               [21, 22, 23, 24, 25]  PU116F005-G11
# 81                 [15-16a, 11a-12a, 13a-14a, 9a-10a]  L0424K00Y-K11
# 82                    [8-10a, 10-12a, 12-13a, 13-15a]  N1243G022-C11
# 83                 [35.5, 36, 36.5, 37.5, 38, 39, 40]  NS414D005-K23
#
#                                               url_key
# 0        guess-small-backpack-sac-a-dos-gu153i00g-q11
# 1    esprit-pants-jean-slim-medium-wash-es124a08b-k11
# 2   jackandjones-junior-jorhotel-tee-crew-neck-jun...
# 3   name-it-dress-campmini-robe-en-jersey-dark-sap...
# 4             gap-march-t-shirt-imprime-gp024g0fg-e11
# 5          quiksilver-veste-dhiver-navy-qu124l01v-k11
# 6   benetton-dress-robe-en-jersey-whiteblack-4be23...
# 7                 benetton-chemise-blue-4be24i023-k15
# 8   staccato-bermudas-2-pack-short-indigo-structur...
# 9         benetton-dress-robe-en-jersey-4be23f083-i11
# 10                  benetton-basic-polo-4be23g0du-k11
# 11                  benetton-basic-polo-4be23g0du-a11
# 12  nike-performance-hoodie-veste-en-sweat-zippee-...
# 13        lacoste-boy-chapeau-navy-blue-la253m003-k11
# 14  nike-sportswear-md-runner-2-baskets-basses-ni1...
# 15  nike-performance-air-max-bodysuit-bootie-set-s...
# 16    esprit-pants-jean-slim-watermelon-es123a099-g11
# 17  sunnylife-giraffe-kids-lunch-bag-sac-a-main-ye...
# 18    benetton-trousers-basic-jean-slim-4be24a05p-h11
# 19  nike-performance-air-hoodie-veste-en-sweat-zip...
# 20  blue-effect-boys-pantalon-de-survetement-nacht...
# 21                re-gen-teens-pullover-rg524k00q-c11
# 22  polo-ralph-lauren-apparel-accessories-hat-baby...
# 23  lmtd-nlfdamier-o-neck-sweatshirt-moonbeam-l042...
# 24  nike-performance-dry-academy-pant-pantalon-de-...
# 25  3-pommes-dress-manches-robe-dete-broken-white-...
# 26               ovs-stripes-polo-righe-ov024g0ac-c11
# 27  adidas-performance-sweatshirt-medium-grey-heat...
# 28  benetton-jacket-basic-veste-dhiver-dark-blue-4...
# 29  pepe-jeans-belle-hearth-baskets-basses-white-p...
# ..                                                ...
# 54  zalando-essentials-kids-pantalon-de-survetemen...
# 55         re-gen-t-shirt-imprime-black-rg524g02g-q11
# 56     friboo-sweatshirt-mineral-yellow-f5723k022-e11
# 57  polo-ralph-lauren-stripe-one-piece-combinaison...
# 58  lacoste-boy-sweatshirt-salvianavy-bluesilver-c...
# 59  friboo-go-for-it-t-shirt-imprime-orchid-bouque...
# 60  sonia-rykiel-cookie-sac-a-main-vanille-sy953i0...
# 61  nike-performance-cr7-dry-t-shirt-de-sport-blac...
# 62  friboo-no-rules-crop-hoody-sweatshirt-purple-w...
# 63  benetton-trousers-basic-chino-khaki-4be24b03k-n11
# 64        benetton-t-shirt-imprime-blue-4be24g0ce-k11
# 65       gap-girls-yoke-t-shirt-imprime-gp023g0c1-c11
# 66  benetton-bermuda-basic-short-dark-red-4be24c02...
# 67  name-it-nmfmello-jacket-unicornsmini-veste-mi-...
# 68  converse-first-star-chaussons-pour-bebe-co413a...
# 69  ovs-striped-dress-girl-robe-en-jersey-chinese-...
# 70  abercrombie-and-fitch-graphic-t-shirt-a-manche...
# 71  champion-american-classics-hooded-veste-en-swe...
# 72  retour-jeans-zita-jeans-skinny-medium-blue-rj2...
# 73  tom-tailor-placed-print-t-shirt-a-manches-long...
# 74  mini-molly-star-girls-short-navy-blue-mm723c00...
# 75         esprit-t-shirt-imprime-white-es124g0hk-a11
# 76       name-it-sweatshirt-sky-captain-na823k0e0-c11
# 77  gap-toddler-boy-patch-polo-new-coral-gp024g0ef...
# 78    esprit-t-shirt-imprime-soft-green-es124g0ia-m11
# 79  abercrombie-and-fitch-colorblock-crew-sweatshi...
# 80  puma-sesame-50-baskets-basses-cherry-tomatowhi...
# 81  lmtd-nlmrami-sweatshirt-sky-captain-l0424k00y-k11
# 82     nike-performance-ya76-sweatshirt-n1243g022-c11
# 83  nike-sb-stefan-janoski-chaussures-de-skate-ns4...
#
# [84 rows x 17 columns]

# %% [markdown]
# #### Collect all the objects from selected filters. Total number of pages can be found in the same json. Use *sku* column as index.
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having family_articles, flags, media and sizes remaining lists (they are exceptions).

# %%
# Get the total number of pages
total_pages=results['pagination']['page_count']
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36'
header = {'user-agent': user_agent}

# Your code
df=pd.DataFrame()
for i in range(total_pages):
    k=84*i
    url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset={k}&sort=sale'
    response = requests.get(url, headers=header)
    results = response.json()
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1)

df
# Out:
# C:\Users\Laura\AppData\Roaming\Python\Python36\site-packages\pandas\core\frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#               amount         brand_name  \
# sku
# N1243D11U-Q11    NaN   Nike Performance
# NI114D09A-Q13    NaN    Nike Sportswear
# N1243L00A-Q11    NaN   Nike Performance
# N1243E0J0-Q11    NaN   Nike Performance
# PU113F00E-Q11    NaN               Puma
# N1243A0XZ-C11   82 g   Nike Performance
# N1243G01D-N11    NaN   Nike Performance
# F5723K01F-G11    NaN             Friboo
# RE016D03K-A11    NaN     Reebok Classic
# N1243G09R-Q11    NaN   Nike Performance
# 4BE23F089-J11    NaN           Benetton
# NI114D0AG-A11    NaN    Nike Sportswear
# CO423G018-A11    NaN           Converse
# TO114D01B-K11    NaN     Tommy Hilfiger
# QU124G066-Q11    NaN         Quiksilver
# N1243G09W-Q11    NaN   Nike Performance
# N1243F049-Q11    NaN   Nike Performance
# N1243E0JE-K11    NaN   Nike Performance
# NA823C08I-K12    NaN            Name it
# N1243G022-N11    NaN   Nike Performance
# NI114D057-Q11    NaN    Nike Sportswear
# C7643G02Z-T11    NaN           Champion
# GP024G0E8-C11    NaN                GAP
# GRF23E001-G11    NaN              Grunt
# OV024G09Q-K11    NaN                OVS
# GP024K067-K12    NaN                GAP
# N1243G0AJ-C11    NaN   Nike Performance
# AD116D0K2-C11    NaN   adidas Originals
# JOC43A00U-G11    NaN             Jordan
# C2723G01R-A11    NaN           Catimini
# ...              ...                ...
# N1424G0AB-C11    NaN            Noppies
# N1423J02P-J11    NaN            Noppies
# NX324D03C-K11    NaN               Next
# N1424G0AJ-K11    NaN            Noppies
# N1424K03V-A11    NaN            Noppies
# N1423G08X-J11    NaN            Noppies
# N1423G089-A11    NaN            Noppies
# N1426B028-O11    NaN            Noppies
# N1426B02O-A11    NaN            Noppies
# N1424G0AN-K11    NaN            Noppies
# N1426B02N-K11    NaN            Noppies
# P6824G08E-G11    NaN  Petrol Industries
# N1424L010-Q11    NaN            Noppies
# N1426J00V-E11    NaN            Noppies
# N1422G000-O11    NaN            Noppies
# N1426G01Y-O11    NaN            Noppies
# N1426K018-K11    NaN            Noppies
# N1424G0AO-J11    NaN            Noppies
# N1422S000-C11    NaN            Noppies
# N1486A00E-O11    NaN            Noppies
# AD116D0KA-C11    NaN   adidas Originals
# CO414F00Z-K11    NaN           Converse
# RI913B008-K11    NaN       River Island
# BO914D003-A11    NaN      BOSS Kidswear
# GP084C01W-G11    NaN                GAP
# LE224I01M-K11    NaN            Levi's®
# N1243K0A8-Q11    NaN   Nike Performance
# NI114F00H-K11    NaN    Nike Sportswear
# V2023E00K-J11    NaN            Vingino
# VA443G008-K11    NaN              Vaude
#
#                                                  family_articles  \
# sku
# N1243D11U-Q11  [{'sku': 'N1243D11U-Q11', 'url_key': 'nike-per...
# NI114D09A-Q13  [{'sku': 'NI114D09A-Q13', 'url_key': 'nike-spo...
# N1243L00A-Q11  [{'sku': 'N1243L00A-Q11', 'url_key': 'nike-per...
# N1243E0J0-Q11  [{'sku': 'N1243E0J0-Q11', 'url_key': 'nike-per...
# PU113F00E-Q11  [{'sku': 'PU113F00E-Q11', 'url_key': 'puma-bow...
# N1243A0XZ-C11  [{'sku': 'N1243A0XZ-C11', 'url_key': 'nike-per...
# N1243G01D-N11  [{'sku': 'N1243G01D-N11', 'url_key': 'nike-per...
# F5723K01F-G11  [{'sku': 'F5723K01F-G11', 'url_key': 'friboo-s...
# RE016D03K-A11  [{'sku': 'RE016D03K-A11', 'url_key': 'reebok-c...
# N1243G09R-Q11  [{'sku': 'N1243G09R-Q11', 'url_key': 'nike-per...
# 4BE23F089-J11  [{'sku': '4BE23F089-J11', 'url_key': 'benetton...
# NI114D0AG-A11  [{'sku': 'NI114D0AG-A11', 'url_key': 'nike-spo...
# CO423G018-A11  [{'sku': 'CO423G018-A11', 'url_key': 'converse...
# TO114D01B-K11  [{'sku': 'TO114D01B-K11', 'url_key': 'tommy-hi...
# QU124G066-Q11  [{'sku': 'QU124G066-Q11', 'url_key': 'quiksilv...
# N1243G09W-Q11  [{'sku': 'N1243G09W-Q11', 'url_key': 'nike-per...
# N1243F049-Q11  [{'sku': 'N1243F049-Q11', 'url_key': 'nike-per...
# N1243E0JE-K11  [{'sku': 'N1243E0JE-K11', 'url_key': 'nike-per...
# NA823C08I-K12  [{'sku': 'NA823C08I-K12', 'url_key': 'name-it-...
# N1243G022-N11  [{'sku': 'N1243G022-N11', 'url_key': 'nike-per...
# NI114D057-Q11  [{'sku': 'NI114D057-Q11', 'url_key': 'nike-spo...
# C7643G02Z-T11  [{'sku': 'C7643G02Z-T11', 'url_key': 'champion...
# GP024G0E8-C11  [{'sku': 'GP024G0E8-C11', 'url_key': 'gap-todd...
# GRF23E001-G11  [{'sku': 'GRF23E001-G11', 'url_key': 'grunt-eg...
# OV024G09Q-K11  [{'sku': 'OV024G09Q-K11', 'url_key': 'ovs-2-pa...
# GP024K067-K12  [{'sku': 'GP024K067-K12', 'url_key': 'gap-boys...
# N1243G0AJ-C11  [{'sku': 'N1243G0AJ-C11', 'url_key': 'nike-per...
# AD116D0K2-C11  [{'sku': 'AD116D0K2-C11', 'url_key': 'adidas-o...
# JOC43A00U-G11  [{'sku': 'JOC43A00U-G11', 'url_key': 'jordan-w...
# C2723G01R-A11  [{'sku': 'C2723G01R-A11', 'url_key': 'catimini...
# ...                                                          ...
# N1424G0AB-C11  [{'sku': 'N1424G0AB-C11', 'url_key': 'noppies-...
# N1423J02P-J11  [{'sku': 'N1423J02P-J11', 'url_key': 'noppies-...
# NX324D03C-K11  [{'sku': 'NX324D03C-K11', 'url_key': 'next-sal...
# N1424G0AJ-K11  [{'sku': 'N1424G0AJ-K11', 'url_key': 'noppies-...
# N1424K03V-A11  [{'sku': 'N1424K03V-A11', 'url_key': 'noppies-...
# N1423G08X-J11  [{'sku': 'N1423G08X-J11', 'url_key': 'noppies-...
# N1423G089-A11  [{'sku': 'N1423G089-A11', 'url_key': 'noppies-...
# N1426B028-O11  [{'sku': 'N1426B028-O11', 'url_key': 'noppies-...
# N1426B02O-A11  [{'sku': 'N1426B02O-A11', 'url_key': 'noppies-...
# N1424G0AN-K11  [{'sku': 'N1424G0AN-K11', 'url_key': 'noppies-...
# N1426B02N-K11  [{'sku': 'N1426B02N-K11', 'url_key': 'noppies-...
# P6824G08E-G11  [{'sku': 'P6824G08E-G11', 'url_key': 'petrol-i...
# N1424L010-Q11  [{'sku': 'N1424L010-Q11', 'url_key': 'noppies-...
# N1426J00V-E11  [{'sku': 'N1426J00V-E11', 'url_key': 'noppies-...
# N1422G000-O11  [{'sku': 'N1422G000-O11', 'url_key': 'noppies-...
# N1426G01Y-O11  [{'sku': 'N1426G01Y-O11', 'url_key': 'noppies-...
# N1426K018-K11  [{'sku': 'N1426K018-K11', 'url_key': 'noppies-...
# N1424G0AO-J11  [{'sku': 'N1424G0AO-J11', 'url_key': 'noppies-...
# N1422S000-C11  [{'sku': 'N1422S000-C11', 'url_key': 'noppies-...
# N1486A00E-O11  [{'sku': 'N1486A00E-O11', 'url_key': 'noppies-...
# AD116D0KA-C11  [{'sku': 'AD116D0KA-C11', 'url_key': 'adidas-o...
# CO414F00Z-K11  [{'sku': 'CO414F00Z-K11', 'url_key': 'converse...
# RI913B008-K11  [{'sku': 'RI913B008-K11', 'url_key': 'river-is...
# BO914D003-A11  [{'sku': 'BO914D003-A11', 'url_key': 'boss-kid...
# GP084C01W-G11  [{'sku': 'GP084C01W-G11', 'url_key': 'gap-swim...
# LE224I01M-K11  [{'sku': 'LE224I01M-K11', 'url_key': 'levisr-s...
# N1243K0A8-Q11  [{'sku': 'N1243K0A8-Q11', 'url_key': 'nike-per...
# NI114F00H-K11  [{'sku': 'NI114F00H-K11', 'url_key': 'nike-spo...
# V2023E00K-J11  [{'sku': 'V2023E00K-J11', 'url_key': 'vingino-...
# VA443G008-K11  [{'sku': 'VA443G008-K11', 'url_key': 'vaude-ki...
#
#                                                            flags  is_premium  \
# sku
# N1243D11U-Q11  [{'key': 'sponsored', 'value': 'Sponsorisé', '...       False
# NI114D09A-Q13  [{'key': 'sponsored', 'value': 'Sponsorisé', '...       False
# N1243L00A-Q11  [{'key': 'sponsored', 'value': 'Sponsorisé', '...       False
# N1243E0J0-Q11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# PU113F00E-Q11  [{'key': 'discountRate', 'value': 'Jusqu’à -70...       False
# N1243A0XZ-C11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# N1243G01D-N11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# F5723K01F-G11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# RE016D03K-A11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# N1243G09R-Q11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 4BE23F089-J11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# NI114D0AG-A11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# CO423G018-A11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# TO114D01B-K11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...        True
# QU124G066-Q11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# N1243G09W-Q11  [{'key': 'sponsored', 'value': 'Sponsorisé', '...       False
# N1243F049-Q11  [{'key': 'sponsored', 'value': 'Sponsorisé', '...       False
# N1243E0JE-K11  [{'key': 'sponsored', 'value': 'Sponsorisé', '...       False
# NA823C08I-K12  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# N1243G022-N11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# NI114D057-Q11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# C7643G02Z-T11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# GP024G0E8-C11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# GRF23E001-G11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# OV024G09Q-K11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# GP024K067-K12  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# N1243G0AJ-C11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# AD116D0K2-C11  [{'key': 'discountRate', 'value': 'Jusqu’à -70...       False
# JOC43A00U-G11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# C2723G01R-A11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...        True
# ...                                                          ...         ...
# N1424G0AB-C11                                                 []       False
# N1423J02P-J11                                                 []       False
# NX324D03C-K11  [{'key': 'campaign', 'value': 'PRIX MINI', 'tr...       False
# N1424G0AJ-K11                                                 []       False
# N1424K03V-A11                                                 []       False
# N1423G08X-J11  [{'key': 'csr', 'value': 'Éco-responsable', 't...       False
# N1423G089-A11                                                 []       False
# N1426B028-O11  [{'key': 'csr', 'value': 'Éco-responsable', 't...       False
# N1426B02O-A11  [{'key': 'csr', 'value': 'Éco-responsable', 't...       False
# N1424G0AN-K11                                                 []       False
# N1426B02N-K11  [{'key': 'csr', 'value': 'Éco-responsable', 't...       False
# P6824G08E-G11  [{'key': 'discountRate', 'value': 'Jusqu’à -33...       False
# N1424L010-Q11                                                 []       False
# N1426J00V-E11  [{'key': 'csr', 'value': 'Éco-responsable', 't...       False
# N1422G000-O11                                                 []       False
# N1426G01Y-O11  [{'key': 'csr', 'value': 'Éco-responsable', 't...       False
# N1426K018-K11  [{'key': 'csr', 'value': 'Éco-responsable', 't...       False
# N1424G0AO-J11                                                 []       False
# N1422S000-C11  [{'key': 'csr', 'value': 'Éco-responsable', 't...       False
# N1486A00E-O11  [{'key': 'csr', 'value': 'Éco-responsable', 't...       False
# AD116D0KA-C11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# CO414F00Z-K11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# RI913B008-K11  [{'key': 'discountRate', 'value': '-50%', 'tra...       False
# BO914D003-A11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...        True
# GP084C01W-G11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# LE224I01M-K11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# N1243K0A8-Q11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# NI114F00H-K11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# V2023E00K-J11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# VA443G008-K11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
#
#                                                            media  \
# sku
# N1243D11U-Q11  [{'path': 'N1/24/3D/11/UQ/11/N1243D11U-Q11@12....
# NI114D09A-Q13  [{'path': 'NI/11/4D/09/AQ/13/NI114D09A-Q13@6.j...
# N1243L00A-Q11  [{'path': 'N1/24/3L/00/AQ/11/N1243L00A-Q11@11....
# N1243E0J0-Q11  [{'path': 'N1/24/3E/0J/0Q/11/N1243E0J0-Q11@4.j...
# PU113F00E-Q11  [{'path': 'PU/11/3F/00/EQ/11/PU113F00E-Q11@11....
# N1243A0XZ-C11  [{'path': 'N1/24/3A/0X/ZC/11/N1243A0XZ-C11@9.j...
# N1243G01D-N11  [{'path': 'N1/24/3G/01/DN/11/N1243G01D-N11@4.j...
# F5723K01F-G11  [{'path': 'F5/72/3K/01/FG/11/F5723K01F-G11@3.j...
# RE016D03K-A11  [{'path': 'RE/01/6D/03/KA/11/RE016D03K-A11@2.1...
# N1243G09R-Q11  [{'path': 'N1/24/3G/09/RQ/11/N1243G09R-Q11@9.j...
# 4BE23F089-J11  [{'path': '4B/E2/3F/08/9J/11/4BE23F089-J11@8.j...
# NI114D0AG-A11  [{'path': 'NI/11/4D/0A/GA/11/NI114D0AG-A11@8.j...
# CO423G018-A11  [{'path': 'CO/42/3G/01/8A/11/CO423G018-A11@8.j...
# TO114D01B-K11  [{'path': 'TO/11/4D/01/BK/11/TO114D01B-K11@9.j...
# QU124G066-Q11  [{'path': 'QU/12/4G/06/6Q/11/QU124G066-Q11@4.j...
# N1243G09W-Q11  [{'path': 'N1/24/3G/09/WQ/11/N1243G09W-Q11@9.j...
# N1243F049-Q11  [{'path': 'N1/24/3F/04/9Q/11/N1243F049-Q11@16....
# N1243E0JE-K11  [{'path': 'N1/24/3E/0J/EK/11/N1243E0JE-K11@6.j...
# NA823C08I-K12  [{'path': 'NA/82/3C/08/IK/12/NA823C08I-K12@4.j...
# N1243G022-N11  [{'path': 'N1/24/3G/02/2N/11/N1243G022-N11@4.j...
# NI114D057-Q11  [{'path': 'NI/11/4D/05/7Q/11/NI114D057-Q11@12....
# C7643G02Z-T11  [{'path': 'C7/64/3G/02/ZT/11/C7643G02Z-T11@2.j...
# GP024G0E8-C11  [{'path': 'GP/02/4G/0E/8C/11/GP024G0E8-C11@6.j...
# GRF23E001-G11  [{'path': 'GR/F2/3E/00/1G/11/GRF23E001-G11@2.j...
# OV024G09Q-K11  [{'path': 'OV/02/4G/09/QK/11/OV024G09Q-K11@10....
# GP024K067-K12  [{'path': 'GP/02/4K/06/7K/12/GP024K067-K12@2.j...
# N1243G0AJ-C11  [{'path': 'N1/24/3G/0A/JC/11/N1243G0AJ-C11@7.j...
# AD116D0K2-C11  [{'path': 'AD/11/6D/0K/2C/11/AD116D0K2-C11@3.j...
# JOC43A00U-G11  [{'path': 'JO/C4/3A/00/UG/11/JOC43A00U-G11@11....
# C2723G01R-A11  [{'path': 'C2/72/3G/01/RA/11/C2723G01R-A11@2.j...
# ...                                                          ...
# N1424G0AB-C11  [{'path': 'N1/42/4G/0A/BC/11/N1424G0AB-C11@9.j...
# N1423J02P-J11  [{'path': 'N1/42/3J/02/PJ/11/N1423J02P-J11@15....
# NX324D03C-K11  [{'path': 'NX/32/4D/03/CK/11/NX324D03C-K11@1.1...
# N1424G0AJ-K11  [{'path': 'N1/42/4G/0A/JK/11/N1424G0AJ-K11@2.1...
# N1424K03V-A11  [{'path': 'N1/42/4K/03/VA/11/N1424K03V-A11@2.1...
# N1423G08X-J11  [{'path': 'N1/42/3G/08/XJ/11/N1423G08X-J11@9.j...
# N1423G089-A11  [{'path': 'N1/42/3G/08/9A/11/N1423G089-A11@8.j...
# N1426B028-O11  [{'path': 'N1/42/6B/02/8O/11/N1426B028-O11@2.1...
# N1426B02O-A11  [{'path': 'N1/42/6B/02/OA/11/N1426B02O-A11@1.1...
# N1424G0AN-K11  [{'path': 'N1/42/4G/0A/NK/11/N1424G0AN-K11@16....
# N1426B02N-K11  [{'path': 'N1/42/6B/02/NK/11/N1426B02N-K11@1.1...
# P6824G08E-G11  [{'path': 'P6/82/4G/08/EG/11/P6824G08E-G11@10....
# N1424L010-Q11  [{'path': 'N1/42/4L/01/0Q/11/N1424L010-Q11@6.1...
# N1426J00V-E11  [{'path': 'N1/42/6J/00/VE/11/N1426J00V-E11@1.1...
# N1422G000-O11  [{'path': 'N1/42/2G/00/0O/11/N1422G000-O11@1.1...
# N1426G01Y-O11  [{'path': 'N1/42/6G/01/YO/11/N1426G01Y-O11@9.j...
# N1426K018-K11  [{'path': 'N1/42/6K/01/8K/11/N1426K018-K11@2.1...
# N1424G0AO-J11  [{'path': 'N1/42/4G/0A/OJ/11/N1424G0AO-J11@9.1...
# N1422S000-C11  [{'path': 'N1/42/2S/00/0C/11/N1422S000-C11@15....
# N1486A00E-O11  [{'path': 'N1/48/6A/00/EO/11/N1486A00E-O11@7.j...
# AD116D0KA-C11  [{'path': 'AD/11/6D/0K/AC/11/AD116D0KA-C11@11....
# CO414F00Z-K11  [{'path': 'CO/41/4F/00/ZK/11/CO414F00Z-K11@3.j...
# RI913B008-K11  [{'path': 'RI/91/3B/00/8K/11/RI913B008-K11@10....
# BO914D003-A11  [{'path': 'BO/91/4D/00/3A/11/BO914D003-A11@9.j...
# GP084C01W-G11  [{'path': 'GP/08/4C/01/WG/11/GP084C01W-G11@7.j...
# LE224I01M-K11  [{'path': 'LE/22/4I/01/MK/11/LE224I01M-K11@4.j...
# N1243K0A8-Q11  [{'path': 'N1/24/3K/0A/8Q/11/N1243K0A8-Q11@4.j...
# NI114F00H-K11  [{'path': 'NI/11/4F/00/HK/11/NI114F00H-K11@19....
# V2023E00K-J11  [{'path': 'V2/02/3E/00/KJ/11/V2023E00K-J11@2.j...
# VA443G008-K11  [{'path': 'VA/44/3G/00/8K/11/VA443G008-K11@4.j...
#
#                                                             name  \
# sku
# N1243D11U-Q11                DRY - T-shirt imprimé - black/white
# NI114D09A-Q13         AIR MAX 720 - Baskets basses - grey/orange
# N1243L00A-Q11            SKIRT AIR - Jupe de sport - black/white
# N1243E0J0-Q11         AIR PANT - Pantalon de survêtement - black
# PU113F00E-Q11        BOW - Mocassins - black/glacier gray/silver
# N1243A0XZ-C11  FLEX RUNNER - Chaussures de running neutres - ...
# N1243G01D-N11  FULL ZIP - veste en sweat zippée - cargo khaki...
# F5723K01F-G11                   Sweat à capuche - chrysanthemium
# RE016D03K-A11              WORKOUT PLUS - Baskets basses - white
# N1243G09R-Q11  HOODIE STUDIO - veste en sweat zippée - black/...
# 4BE23F089-J11                    DRESS - Robe d'été - pink/white
# NI114D0AG-A11  AIR MAX AXIS - Baskets basses - white/total or...
# CO423G018-A11                  CHEVRON - T-shirt imprimé - white
# TO114D01B-K11                        Baskets basses - white/blue
# QU124G066-Q11       KIRRA SHAKKA YOUTH - T-shirt imprimé - black
# N1243G09W-Q11     NIKE AIR - veste en sweat zippée - black/white
# N1243F049-Q11           DRY - Veste de survêtement - black/white
# N1243E0JE-K11  DRY SHORT - Short de sport - blue void/total o...
# NA823C08I-K12                  SOFUS - Short en jean - dark blue
# N1243G022-N11                Sweat à capuche - cargo khaki/white
# NI114D057-Q11   COURT BOROUGH  - Chaussures premiers pas - black
# C7643G02Z-T11  CHAMPION X ZALANDO CREWNECK - Sweatshirt - mot...
# GP024G0E8-C11     TODDLER BOY EASTER - Polo - light heather grey
# GRF23E001-G11               EGIL MESS SKIRT - Jupe trapèze - red
# OV024G09Q-K11             2 PACK - T-shirt imprimé - black/white
# GP024K067-K12  BOYS ACTIVE ARCH - veste en sweat zippée - tru...
# N1243G0AJ-C11    CREW AIR - Sweatshirt - ashen slate/black/white
# AD116D0K2-C11  SOBAKOV - Baskets basses - grey one/grey two/f...
# JOC43A00U-G11  WHY NOT  - Chaussures de basket - gym red/blac...
# C2723G01R-A11                      TEE - T-shirt imprimé - craie
# ...                                                          ...
# N1424G0AB-C11  SUMMERFIELD - T-shirt imprimé - light grey mel...
# N1423J02P-J11                                       Gilet - pink
# NX324D03C-K11                                        Body - blue
# N1424G0AJ-K11       SANDPOINT - T-shirt à manches longues - blue
# N1424K03V-A11                                 Sweatshirt - white
# N1423G08X-J11                   SUAMICO - T-shirt imprimé - rose
# N1423G089-A11       T-shirt à manches longues - white/black/pink
# N1426B028-O11                         Pantalon classique - brown
# N1426B02O-A11                         Pantalon classique - white
# N1424G0AN-K11                             T-shirt imprimé - blue
# N1426B02N-K11                          Pantalon classique - blue
# P6824G08E-G11                           T-shirt imprimé - maroon
# N1424L010-Q11                             Veste légère - phantom
# N1426J00V-E11                    PARAMUS - Gilet - canary yellow
# N1422G000-O11                PARAGOULD - Jean slim - washed wood
# N1426G01Y-O11  OVERLAP PLUM BABY ZGREEN - T-shirt à manches l...
# N1426K018-K11       SWEATER ROSSFORD - Sweatshirt - patriot blue
# N1424G0AO-J11                               Blouse - honeysuckle
# N1422S000-C11                                  Sweatshirt - grey
# N1486A00E-O11                                       Body - brown
# AD116D0KA-C11       U_PATH RUN - Mocassins - grey/footwear white
# CO414F00Z-K11  CHUCK TAYLOR ALL STAR STREET MID - Baskets mon...
# RI913B008-K11                                 Espadrilles - blue
# BO914D003-A11             TURNSCHUHE - Baskets montantes - weiss
# GP084C01W-G11             SWIM BABY - Maillot de bain - pure red
# LE224I01M-K11                     SAWTOO BABY - Chemise - indigo
# N1243K0A8-Q11            AIR - Survêtement - black heather/white
# NI114F00H-K11                   LIL - Mocassins - obsidian/white
# V2023E00K-J11                    QALLA - Jupe trapèze - violetti
# VA443G008-K11     KIKIMORA JACKET - Veste polaire - radiate blue
#
#                price.has_different_original_prices  \
# sku
# N1243D11U-Q11                                False
# NI114D09A-Q13                                False
# N1243L00A-Q11                                False
# N1243E0J0-Q11                                False
# PU113F00E-Q11                                False
# N1243A0XZ-C11                                False
# N1243G01D-N11                                False
# F5723K01F-G11                                False
# RE016D03K-A11                                False
# N1243G09R-Q11                                False
# 4BE23F089-J11                                False
# NI114D0AG-A11                                False
# CO423G018-A11                                False
# TO114D01B-K11                                False
# QU124G066-Q11                                False
# N1243G09W-Q11                                False
# N1243F049-Q11                                False
# N1243E0JE-K11                                False
# NA823C08I-K12                                False
# N1243G022-N11                                False
# NI114D057-Q11                                False
# C7643G02Z-T11                                False
# GP024G0E8-C11                                False
# GRF23E001-G11                                False
# OV024G09Q-K11                                False
# GP024K067-K12                                False
# N1243G0AJ-C11                                False
# AD116D0K2-C11                                False
# JOC43A00U-G11                                False
# C2723G01R-A11                                False
# ...                                            ...
# N1424G0AB-C11                                False
# N1423J02P-J11                                False
# NX324D03C-K11                                False
# N1424G0AJ-K11                                False
# N1424K03V-A11                                False
# N1423G08X-J11                                False
# N1423G089-A11                                False
# N1426B028-O11                                False
# N1426B02O-A11                                False
# N1424G0AN-K11                                False
# N1426B02N-K11                                False
# P6824G08E-G11                                 True
# N1424L010-Q11                                False
# N1426J00V-E11                                False
# N1422G000-O11                                False
# N1426G01Y-O11                                False
# N1426K018-K11                                False
# N1424G0AO-J11                                False
# N1422S000-C11                                False
# N1486A00E-O11                                False
# AD116D0KA-C11                                False
# CO414F00Z-K11                                False
# RI913B008-K11                                False
# BO914D003-A11                                False
# GP084C01W-G11                                False
# LE224I01M-K11                                False
# N1243K0A8-Q11                                False
# NI114F00H-K11                                False
# V2023E00K-J11                                False
# VA443G008-K11                                False
#
#                price.has_different_prices  \
# sku
# N1243D11U-Q11                        True
# NI114D09A-Q13                        True
# N1243L00A-Q11                       False
# N1243E0J0-Q11                        True
# PU113F00E-Q11                        True
# N1243A0XZ-C11                       False
# N1243G01D-N11                       False
# F5723K01F-G11                        True
# RE016D03K-A11                       False
# N1243G09R-Q11                       False
# 4BE23F089-J11                       False
# NI114D0AG-A11                        True
# CO423G018-A11                       False
# TO114D01B-K11                        True
# QU124G066-Q11                       False
# N1243G09W-Q11                        True
# N1243F049-Q11                        True
# N1243E0JE-K11                        True
# NA823C08I-K12                       False
# N1243G022-N11                        True
# NI114D057-Q11                       False
# C7643G02Z-T11                       False
# GP024G0E8-C11                       False
# GRF23E001-G11                       False
# OV024G09Q-K11                       False
# GP024K067-K12                       False
# N1243G0AJ-C11                        True
# AD116D0K2-C11                        True
# JOC43A00U-G11                        True
# C2723G01R-A11                        True
# ...                                   ...
# N1424G0AB-C11                       False
# N1423J02P-J11                       False
# NX324D03C-K11                       False
# N1424G0AJ-K11                       False
# N1424K03V-A11                       False
# N1423G08X-J11                       False
# N1423G089-A11                       False
# N1426B028-O11                       False
# N1426B02O-A11                       False
# N1424G0AN-K11                       False
# N1426B02N-K11                       False
# P6824G08E-G11                       False
# N1424L010-Q11                       False
# N1426J00V-E11                       False
# N1422G000-O11                       False
# N1426G01Y-O11                       False
# N1426K018-K11                       False
# N1424G0AO-J11                       False
# N1422S000-C11                       False
# N1486A00E-O11                       False
# AD116D0KA-C11                       False
# CO414F00Z-K11                       False
# RI913B008-K11                       False
# BO914D003-A11                       False
# GP084C01W-G11                       False
# LE224I01M-K11                       False
# N1243K0A8-Q11                       False
# NI114F00H-K11                       False
# V2023E00K-J11                       False
# VA443G008-K11                       False
#
#                price.has_different_promotional_prices  \
# sku
# N1243D11U-Q11                                    True
# NI114D09A-Q13                                    True
# N1243L00A-Q11                                   False
# N1243E0J0-Q11                                    True
# PU113F00E-Q11                                    True
# N1243A0XZ-C11                                   False
# N1243G01D-N11                                   False
# F5723K01F-G11                                    True
# RE016D03K-A11                                   False
# N1243G09R-Q11                                   False
# 4BE23F089-J11                                   False
# NI114D0AG-A11                                    True
# CO423G018-A11                                   False
# TO114D01B-K11                                    True
# QU124G066-Q11                                   False
# N1243G09W-Q11                                    True
# N1243F049-Q11                                    True
# N1243E0JE-K11                                    True
# NA823C08I-K12                                   False
# N1243G022-N11                                    True
# NI114D057-Q11                                   False
# C7643G02Z-T11                                   False
# GP024G0E8-C11                                   False
# GRF23E001-G11                                   False
# OV024G09Q-K11                                   False
# GP024K067-K12                                   False
# N1243G0AJ-C11                                    True
# AD116D0K2-C11                                    True
# JOC43A00U-G11                                    True
# C2723G01R-A11                                    True
# ...                                               ...
# N1424G0AB-C11                                   False
# N1423J02P-J11                                   False
# NX324D03C-K11                                   False
# N1424G0AJ-K11                                   False
# N1424K03V-A11                                   False
# N1423G08X-J11                                   False
# N1423G089-A11                                   False
# N1426B028-O11                                   False
# N1426B02O-A11                                   False
# N1424G0AN-K11                                   False
# N1426B02N-K11                                   False
# P6824G08E-G11                                   False
# N1424L010-Q11                                   False
# N1426J00V-E11                                   False
# N1422G000-O11                                   False
# N1426G01Y-O11                                   False
# N1426K018-K11                                   False
# N1424G0AO-J11                                   False
# N1422S000-C11                                   False
# N1486A00E-O11                                   False
# AD116D0KA-C11                                   False
# CO414F00Z-K11                                   False
# RI913B008-K11                                   False
# BO914D003-A11                                   False
# GP084C01W-G11                                   False
# LE224I01M-K11                                   False
# N1243K0A8-Q11                                   False
# NI114F00H-K11                                   False
# V2023E00K-J11                                   False
# VA443G008-K11                                   False
#
#                price.has_discount_on_selected_sizes_only price.original  \
# sku
# N1243D11U-Q11                                      False        24,95 €
# NI114D09A-Q13                                      False       149,95 €
# N1243L00A-Q11                                      False        34,95 €
# N1243E0J0-Q11                                      False        44,95 €
# PU113F00E-Q11                                      False        54,95 €
# N1243A0XZ-C11                                      False        29,95 €
# N1243G01D-N11                                      False        39,95 €
# F5723K01F-G11                                      False        17,95 €
# RE016D03K-A11                                      False        59,95 €
# N1243G09R-Q11                                      False        44,95 €
# 4BE23F089-J11                                      False        25,95 €
# NI114D0AG-A11                                      False        69,95 €
# CO423G018-A11                                      False        34,95 €
# TO114D01B-K11                                      False        64,95 €
# QU124G066-Q11                                      False        15,99 €
# N1243G09W-Q11                                      False        49,95 €
# N1243F049-Q11                                      False        39,95 €
# N1243E0JE-K11                                      False        24,95 €
# NA823C08I-K12                                      False        16,95 €
# N1243G022-N11                                      False        34,95 €
# NI114D057-Q11                                      False        29,95 €
# C7643G02Z-T11                                      False        24,95 €
# GP024G0E8-C11                                      False        14,95 €
# GRF23E001-G11                                      False        34,95 €
# OV024G09Q-K11                                      False        24,95 €
# GP024K067-K12                                      False        29,95 €
# N1243G0AJ-C11                                      False        39,95 €
# AD116D0K2-C11                                      False        89,95 €
# JOC43A00U-G11                                      False        94,95 €
# C2723G01R-A11                                      False        38,95 €
# ...                                                  ...            ...
# N1424G0AB-C11                                      False        14,99 €
# N1423J02P-J11                                      False        39,99 €
# NX324D03C-K11                                      False        34,95 €
# N1424G0AJ-K11                                      False        14,99 €
# N1424K03V-A11                                      False        34,99 €
# N1423G08X-J11                                      False        17,99 €
# N1423G089-A11                                      False        19,99 €
# N1426B028-O11                                      False        22,99 €
# N1426B02O-A11                                      False        22,99 €
# N1424G0AN-K11                                      False        14,99 €
# N1426B02N-K11                                      False        18,99 €
# P6824G08E-G11                                      False        19,99 €
# N1424L010-Q11                                      False        49,99 €
# N1426J00V-E11                                      False        34,99 €
# N1422G000-O11                                      False        37,99 €
# N1426G01Y-O11                                      False        22,99 €
# N1426K018-K11                                      False        29,99 €
# N1424G0AO-J11                                      False        17,99 €
# N1422S000-C11                                      False        29,99 €
# N1486A00E-O11                                      False        16,99 €
# AD116D0KA-C11                                      False        44,95 €
# CO414F00Z-K11                                      False        49,95 €
# RI913B008-K11                                      False        18,00 €
# BO914D003-A11                                      False       129,95 €
# GP084C01W-G11                                      False        27,95 €
# LE224I01M-K11                                      False        49,95 €
# N1243K0A8-Q11                                      False        59,95 €
# NI114F00H-K11                                      False        29,95 €
# V2023E00K-J11                                      False        39,99 €
# VA443G008-K11                                      False        59,95 €
#
#               price.promotional product_group  \
# sku
# N1243D11U-Q11           19,95 €      clothing
# NI114D09A-Q13           90,00 €          shoe
# N1243L00A-Q11           24,46 €      clothing
# N1243E0J0-Q11           13,49 €      clothing
# PU113F00E-Q11           16,45 €          shoe
# N1243A0XZ-C11           18,00 €          shoe
# N1243G01D-N11           16,00 €      clothing
# F5723K01F-G11            5,40 €      clothing
# RE016D03K-A11           21,00 €          shoe
# N1243G09R-Q11           18,00 €      clothing
# 4BE23F089-J11            7,79 €      clothing
# NI114D0AG-A11           49,00 €          shoe
# CO423G018-A11           10,49 €      clothing
# TO114D01B-K11           45,46 €          shoe
# QU124G066-Q11            8,00 €      clothing
# N1243G09W-Q11           40,00 €      clothing
# N1243F049-Q11           24,00 €      clothing
# N1243E0JE-K11           20,00 €      clothing
# NA823C08I-K12            5,09 €      clothing
# N1243G022-N11           17,48 €      clothing
# NI114D057-Q11           24,00 €          shoe
# C7643G02Z-T11           13,70 €      clothing
# GP024G0E8-C11            4,49 €      clothing
# GRF23E001-G11           14,00 €      clothing
# OV024G09Q-K11            7,49 €      clothing
# GP024K067-K12           16,47 €      clothing
# N1243G0AJ-C11           12,00 €      clothing
# AD116D0K2-C11           26,95 €          shoe
# JOC43A00U-G11           27,95 €          shoe
# C2723G01R-A11           11,70 €      clothing
# ...                         ...           ...
# N1424G0AB-C11           14,99 €      clothing
# N1423J02P-J11           39,99 €      clothing
# NX324D03C-K11           34,95 €      clothing
# N1424G0AJ-K11           14,99 €      clothing
# N1424K03V-A11           34,99 €      clothing
# N1423G08X-J11           17,99 €      clothing
# N1423G089-A11           19,99 €      clothing
# N1426B028-O11           22,99 €      clothing
# N1426B02O-A11           22,99 €      clothing
# N1424G0AN-K11           14,99 €      clothing
# N1426B02N-K11           18,99 €      clothing
# P6824G08E-G11           19,99 €      clothing
# N1424L010-Q11           49,99 €      clothing
# N1426J00V-E11           34,99 €      clothing
# N1422G000-O11           37,99 €      clothing
# N1426G01Y-O11           22,99 €      clothing
# N1426K018-K11           29,99 €      clothing
# N1424G0AO-J11           17,99 €      clothing
# N1422S000-C11           29,99 €      clothing
# N1486A00E-O11           16,99 €     underwear
# AD116D0KA-C11           31,46 €          shoe
# CO414F00Z-K11           27,45 €          shoe
# RI913B008-K11            9,00 €          shoe
# BO914D003-A11           57,95 €          shoe
# GP084C01W-G11           22,35 €    beach_wear
# LE224I01M-K11           32,47 €      clothing
# N1243K0A8-Q11           32,95 €      clothing
# NI114F00H-K11           24,00 €          shoe
# V2023E00K-J11           16,00 €      clothing
# VA443G008-K11           26,95 €      clothing
#
#                                                            sizes  \
# sku
# N1243D11U-Q11              [6-8a, 8-10a, 10-12a, 12-13a, 13-15a]
# NI114D09A-Q13           [35.5, 36, 36.5, 37.5, 38, 38.5, 39, 40]
# N1243L00A-Q11                    [8-10a, 10-12a, 12-13a, 13-15a]
# N1243E0J0-Q11              [6-8a, 8-10a, 10-12a, 12-13a, 13-15a]
# PU113F00E-Q11                               [22, 24, 25, 26, 27]
# N1243A0XZ-C11             [17, 18.5, 19.5, 21, 22, 23.5, 25, 26]
# N1243G01D-N11                    [8-10a, 10-12a, 12-13a, 13-15a]
# F5723K01F-G11                  [3-4a, 5-6a, 7-8a, 9-10a, 11-12a]
# RE016D03K-A11                       [34.5, 35, 36, 36.5, 37, 38]
# N1243G09R-Q11              [6-8a, 8-10a, 10-12a, 12-13a, 13-15a]
# 4BE23F089-J11                               [6-7a, 8-9a, 11-12a]
# NI114D0AG-A11  [27.5, 28, 28.5, 29.5, 30, 31, 31.5, 32, 33, 3...
# CO423G018-A11                            [8-10a, 10-12a, 12-13a]
# TO114D01B-K11                   [30, 31, 32, 34, 35, 36, 37, 39]
# QU124G066-Q11                           [8a, 10a, 12a, 14a, 16a]
# N1243G09W-Q11              [6-8a, 8-10a, 10-12a, 12-13a, 13-15a]
# N1243F049-Q11              [6-8a, 8-10a, 10-12a, 12-13a, 13-15a]
# N1243E0JE-K11                    [8-10a, 10-12a, 12-13a, 13-15a]
# NA823C08I-K12         [2a, 3a, 4a, 5a, 6a, 7a, 8a, 9a, 10a, 12a]
# N1243G022-N11                    [8-10a, 10-12a, 12-13a, 13-15a]
# NI114D057-Q11         [17, 18.5, 19.5, 21, 22, 23.5, 25, 26, 27]
# C7643G02Z-T11              [5-6a, 9-10a, 11-12a, 13-14a, 15-16a]
# GP024G0E8-C11                           [2a, 3a, 4a, 5a, 18-24m]
# GRF23E001-G11                               [12a, 14a, 16a, 18a]
# OV024G09Q-K11           [10-11a, 11-12a, 12-13a, 13-14a, 14-15a]
# GP024K067-K12         [4-5a, 6-7a, 8-9a, 10-11a, 12-13a, 14-16a]
# N1243G0AJ-C11              [6-8a, 8-10a, 10-12a, 12-13a, 13-15a]
# AD116D0K2-C11           [36, 38, 35 1/2, 36 2/3, 37 1/3, 38 2/3]
# JOC43A00U-G11               [35.5, 36, 36.5, 37.5, 38, 38.5, 40]
# C2723G01R-A11                         [4a, 5a, 6a, 8a, 10a, 12a]
# ...                                                          ...
# N1424G0AB-C11                          , 2m, 3m, 6m, 9m, 12m]
# N1423J02P-J11                 [3a, 4a, 5a, 6a, 7a, 8a, 18m, 24m]
# NX324D03C-K11                                      [6-9m, 9-12m]
# N1424G0AJ-K11                               , 2m, 3m, 6m, 9m]
# N1424K03V-A11                 [3a, 4a, 5a, 6a, 7a, 8a, 18m, 24m]
# N1423G08X-J11                 [3a, 4a, 5a, 6a, 7a, 8a, 18m, 24m]
# N1423G089-A11                 [3a, 4a, 5a, 6a, 7a, 8a, 18m, 24m]
# N1426B028-O11                      , 1m, 2m, 3m, 6m, 9m, 12m]
# N1426B02O-A11                      , 1m, 2m, 3m, 6m, 9m, 12m]
# N1424G0AN-K11                 [3a, 4a, 5a, 6a, 7a, 8a, 18m, 24m]
# N1426B02N-K11                      , 1m, 2m, 3m, 6m, 9m, 12m]
# P6824G08E-G11                               [10a, 12a, 14a, 16a]
# N1424L010-Q11                 [3a, 4a, 5a, 6a, 7a, 8a, 18m, 24m]
# N1426J00V-E11                      , 1m, 2m, 3m, 6m, 9m, 12m]
# N1422G000-O11                                   [3a, 4a, 5a, 6a]
# N1426G01Y-O11                      , 1m, 2m, 3m, 6m, 9m, 12m]
# N1426K018-K11                 [3a, 4a, 5a, 6a, 7a, 8a, 18m, 24m]
# N1424G0AO-J11                                  [5a, 6a, 7a, 18m]
# N1422S000-C11                           [3a, 4a, 5a, 6a, 7a, 8a]
# N1486A00E-O11                      , 1m, 2m, 3m, 6m, 9m, 12m]
# AD116D0KA-C11                                               [24]
# CO414F00Z-K11                                         [32, 38.5]
# RI913B008-K11                                               [22]
# BO914D003-A11                                               [39]
# GP084C01W-G11                                           [18-24m]
# LE224I01M-K11                                              [24m]
# N1243K0A8-Q11                                           [12-13a]
# NI114F00H-K11                                             [23.5]
# V2023E00K-J11                                         [14a, 16a]
# VA443G008-K11                                           [13-14a]
#
#                           tracking_information.impression_beacon  \
# sku
# N1243D11U-Q11  https://ccp-et.metrigo.zalan.do/event/sbv?z=94...
# NI114D09A-Q13  https://ccp-et.metrigo.zalan.do/event/sbv?z=94...
# N1243L00A-Q11  https://ccp-et.metrigo.zalan.do/event/sbv?z=94...
# N1243E0J0-Q11                                                NaN
# PU113F00E-Q11                                                NaN
# N1243A0XZ-C11                                                NaN
# N1243G01D-N11                                                NaN
# F5723K01F-G11                                                NaN
# RE016D03K-A11                                                NaN
# N1243G09R-Q11                                                NaN
# 4BE23F089-J11                                                NaN
# NI114D0AG-A11                                                NaN
# CO423G018-A11                                                NaN
# TO114D01B-K11                                                NaN
# QU124G066-Q11                                                NaN
# N1243G09W-Q11  https://ccp-et.metrigo.zalan.do/event/sbv?z=94...
# N1243F049-Q11  https://ccp-et.metrigo.zalan.do/event/sbv?z=94...
# N1243E0JE-K11  https://ccp-et.metrigo.zalan.do/event/sbv?z=94...
# NA823C08I-K12                                                NaN
# N1243G022-N11                                                NaN
# NI114D057-Q11                                                NaN
# C7643G02Z-T11                                                NaN
# GP024G0E8-C11                                                NaN
# GRF23E001-G11                                                NaN
# OV024G09Q-K11                                                NaN
# GP024K067-K12                                                NaN
# N1243G0AJ-C11                                                NaN
# AD116D0K2-C11                                                NaN
# JOC43A00U-G11                                                NaN
# C2723G01R-A11                                                NaN
# ...                                                          ...
# N1424G0AB-C11                                                NaN
# N1423J02P-J11                                                NaN
# NX324D03C-K11                                                NaN
# N1424G0AJ-K11                                                NaN
# N1424K03V-A11                                                NaN
# N1423G08X-J11                                                NaN
# N1423G089-A11                                                NaN
# N1426B028-O11                                                NaN
# N1426B02O-A11                                                NaN
# N1424G0AN-K11                                                NaN
# N1426B02N-K11                                                NaN
# P6824G08E-G11                                                NaN
# N1424L010-Q11                                                NaN
# N1426J00V-E11                                                NaN
# N1422G000-O11                                                NaN
# N1426G01Y-O11                                                NaN
# N1426K018-K11                                                NaN
# N1424G0AO-J11                                                NaN
# N1422S000-C11                                                NaN
# N1486A00E-O11                                                NaN
# AD116D0KA-C11                                                NaN
# CO414F00Z-K11                                                NaN
# RI913B008-K11                                                NaN
# BO914D003-A11                                                NaN
# GP084C01W-G11                                                NaN
# LE224I01M-K11                                                NaN
# N1243K0A8-Q11                                                NaN
# NI114F00H-K11                                                NaN
# V2023E00K-J11                                                NaN
# VA443G008-K11                                                NaN
#
#                     tracking_information.metrigo_impression_urls  \
# sku
# N1243D11U-Q11  [https://ccp-et.metrigo.zalan.do/event/sbv?z=9...
# NI114D09A-Q13  [https://ccp-et.metrigo.zalan.do/event/sbv?z=9...
# N1243L00A-Q11  [https://ccp-et.metrigo.zalan.do/event/sbv?z=9...
# N1243E0J0-Q11                                                NaN
# PU113F00E-Q11                                                NaN
# N1243A0XZ-C11                                                NaN
# N1243G01D-N11                                                NaN
# F5723K01F-G11                                                NaN
# RE016D03K-A11                                                NaN
# N1243G09R-Q11                                                NaN
# 4BE23F089-J11                                                NaN
# NI114D0AG-A11                                                NaN
# CO423G018-A11                                                NaN
# TO114D01B-K11                                                NaN
# QU124G066-Q11                                                NaN
# N1243G09W-Q11  [https://ccp-et.metrigo.zalan.do/event/sbv?z=9...
# N1243F049-Q11  [https://ccp-et.metrigo.zalan.do/event/sbv?z=9...
# N1243E0JE-K11  [https://ccp-et.metrigo.zalan.do/event/sbv?z=9...
# NA823C08I-K12                                                NaN
# N1243G022-N11                                                NaN
# NI114D057-Q11                                                NaN
# C7643G02Z-T11                                                NaN
# GP024G0E8-C11                                                NaN
# GRF23E001-G11                                                NaN
# OV024G09Q-K11                                                NaN
# GP024K067-K12                                                NaN
# N1243G0AJ-C11                                                NaN
# AD116D0K2-C11                                                NaN
# JOC43A00U-G11                                                NaN
# C2723G01R-A11                                                NaN
# ...                                                          ...
# N1424G0AB-C11                                                NaN
# N1423J02P-J11                                                NaN
# NX324D03C-K11                                                NaN
# N1424G0AJ-K11                                                NaN
# N1424K03V-A11                                                NaN
# N1423G08X-J11                                                NaN
# N1423G089-A11                                                NaN
# N1426B028-O11                                                NaN
# N1426B02O-A11                                                NaN
# N1424G0AN-K11                                                NaN
# N1426B02N-K11                                                NaN
# P6824G08E-G11                                                NaN
# N1424L010-Q11                                                NaN
# N1426J00V-E11                                                NaN
# N1422G000-O11                                                NaN
# N1426G01Y-O11                                                NaN
# N1426K018-K11                                                NaN
# N1424G0AO-J11                                                NaN
# N1422S000-C11                                                NaN
# N1486A00E-O11                                                NaN
# AD116D0KA-C11                                                NaN
# CO414F00Z-K11                                                NaN
# RI913B008-K11                                                NaN
# BO914D003-A11                                                NaN
# GP084C01W-G11                                                NaN
# LE224I01M-K11                                                NaN
# N1243K0A8-Q11                                                NaN
# NI114F00H-K11                                                NaN
# V2023E00K-J11                                                NaN
# VA443G008-K11                                                NaN
#
#               tracking_information.source  \
# sku
# N1243D11U-Q11                         ccp
# NI114D09A-Q13                         ccp
# N1243L00A-Q11                         ccp
# N1243E0J0-Q11                         NaN
# PU113F00E-Q11                         NaN
# N1243A0XZ-C11                         NaN
# N1243G01D-N11                         NaN
# F5723K01F-G11                         NaN
# RE016D03K-A11                         NaN
# N1243G09R-Q11                         NaN
# 4BE23F089-J11                         NaN
# NI114D0AG-A11                         NaN
# CO423G018-A11                         NaN
# TO114D01B-K11                         NaN
# QU124G066-Q11                         NaN
# N1243G09W-Q11                         ccp
# N1243F049-Q11                         ccp
# N1243E0JE-K11                         ccp
# NA823C08I-K12                         NaN
# N1243G022-N11                         NaN
# NI114D057-Q11                         NaN
# C7643G02Z-T11                         NaN
# GP024G0E8-C11                         NaN
# GRF23E001-G11                         NaN
# OV024G09Q-K11                         NaN
# GP024K067-K12                         NaN
# N1243G0AJ-C11                         NaN
# AD116D0K2-C11                         NaN
# JOC43A00U-G11                         NaN
# C2723G01R-A11                         NaN
# ...                                   ...
# N1424G0AB-C11                         NaN
# N1423J02P-J11                         NaN
# NX324D03C-K11                         NaN
# N1424G0AJ-K11                         NaN
# N1424K03V-A11                         NaN
# N1423G08X-J11                         NaN
# N1423G089-A11                         NaN
# N1426B028-O11                         NaN
# N1426B02O-A11                         NaN
# N1424G0AN-K11                         NaN
# N1426B02N-K11                         NaN
# P6824G08E-G11                         NaN
# N1424L010-Q11                         NaN
# N1426J00V-E11                         NaN
# N1422G000-O11                         NaN
# N1426G01Y-O11                         NaN
# N1426K018-K11                         NaN
# N1424G0AO-J11                         NaN
# N1422S000-C11                         NaN
# N1486A00E-O11                         NaN
# AD116D0KA-C11                         NaN
# CO414F00Z-K11                         NaN
# RI913B008-K11                         NaN
# BO914D003-A11                         NaN
# GP084C01W-G11                         NaN
# LE224I01M-K11                         NaN
# N1243K0A8-Q11                         NaN
# NI114F00H-K11                         NaN
# V2023E00K-J11                         NaN
# VA443G008-K11                         NaN
#
#                                                          url_key
# sku
# N1243D11U-Q11  nike-performance-cr7-dry-t-shirt-de-sport-blac...
# NI114D09A-Q13  nike-sportswear-air-max-720-baskets-basses-ni1...
# N1243L00A-Q11  nike-performance-skirt-air-jupe-de-sport-black...
# N1243E0J0-Q11  nike-performance-air-pant-pantalon-de-survetem...
# PU113F00E-Q11  puma-bow-baskets-basses-blackglacier-graysilve...
# N1243A0XZ-C11  nike-performance-flex-runner-chaussures-de-run...
# N1243G01D-N11  nike-performance-ya76-veste-en-sweat-n1243g01d...
# F5723K01F-G11     friboo-sweatshirt-chrysanthemium-f5723k01f-g11
# RE016D03K-A11  reebok-classic-workout-plus-baskets-basses-whi...
# N1243G09R-Q11  nike-performance-hoodie-studio-veste-en-sweat-...
# 4BE23F089-J11   benetton-dress-robe-dete-pinkwhite-4be23f089-j11
# NI114D0AG-A11  nike-sportswear-air-max-axis-baskets-basses-wh...
# CO423G018-A11  converse-chevron-t-shirt-imprime-white-co423g0...
# TO114D01B-K11  tommy-hilfiger-baskets-basses-whiteblue-to114d...
# QU124G066-Q11  quiksilver-kirra-shakka-youth-t-shirt-imprime-...
# N1243G09W-Q11  nike-performance-nike-air-veste-en-sweat-zippe...
# N1243F049-Q11  nike-performance-cr7-dry-veste-de-survetement-...
# N1243E0JE-K11  nike-performance-dry-short-short-de-sport-n124...
# NA823C08I-K12  name-it-campmini-short-en-jean-dark-blue-na823...
# N1243G022-N11  nike-performance-sweatshirt-cargo-khakiwhite-n...
# NI114D057-Q11  nike-sportswear-court-borough-baskets-basses-n...
# C7643G02Z-T11  champion-champion-x-zalando-crewneck-sweatshir...
# GP024G0E8-C11  gap-toddler-boy-easter-polo-light-heather-grey...
# GRF23E001-G11  grunt-egil-mess-skirt-jupe-trapeze-red-grf23e0...
# OV024G09Q-K11  ovs-2-pack-t-shirt-imprime-blackwhite-ov024g09...
# GP024K067-K12  gap-boys-active-arch-veste-en-sweat-zippee-tru...
# N1243G0AJ-C11  nike-performance-crew-air-sweatshirt-ashen-sla...
# AD116D0K2-C11  adidas-originals-sobakov-baskets-basses-grey-o...
# JOC43A00U-G11  jordan-why-not-chaussures-de-basket-joc43a00u-g11
# C2723G01R-A11   catimini-tee-t-shirt-imprime-craie-c2723g01r-a11
# ...                                                          ...
# N1424G0AB-C11  noppies-t-shirt-imprime-light-grey-melange-n14...
# N1423J02P-J11                   noppies-gilet-pink-n1423j02p-j11
# NX324D03C-K11                  next-salopette-blue-nx324d03c-k11
# N1424G0AJ-K11  noppies-sandpoint-t-shirt-a-manches-longues-bl...
# N1424K03V-A11             noppies-sweatshirt-white-n1424k03v-a11
# N1423G08X-J11         noppies-t-shirt-imprime-rose-n1423g08x-j11
# N1423G089-A11  noppies-t-shirt-a-manches-longues-whiteblackpi...
# N1426B028-O11  noppies-pants-harem-phoenix-baby-pantalon-clas...
# N1426B02O-A11  noppies-pantalon-de-survetement-white-n1426b02...
# N1424G0AN-K11         noppies-t-shirt-imprime-blue-n1424g0an-k11
# N1426B02N-K11      noppies-pantalon-classique-blue-n1426b02n-k11
# P6824G08E-G11  petrol-industries-t-shirt-imprime-maroon-p6824...
# N1424L010-Q11         noppies-veste-legere-phantom-n1424l010-q11
# N1426J00V-E11                 noppies-gilet-yellow-n1426j00v-e11
# N1422G000-O11  noppies-paragould-jean-slim-washed-wood-n1422g...
# N1426G01Y-O11  noppies-overlap-plum-baby-zgreen-t-shirt-a-man...
# N1426K018-K11  noppies-sweater-rossford-sweatshirt-patriot-bl...
# N1424G0AO-J11        noppies-debardeur-honeysuckle-n1424g0ao-j11
# N1422S000-C11              noppies-sweatshirt-grey-n1422s000-c11
# N1486A00E-O11                   noppies-body-brown-n1486a00e-o11
# AD116D0KA-C11  adidas-originals-u_path-run-baskets-basses-gre...
# CO414F00Z-K11  converse-chuck-taylor-all-star-street-mid-bask...
# RI913B008-K11        river-island-espadrilles-blue-ri913b008-k11
# BO914D003-A11  boss-kidswear-turnschuhe-baskets-montantes-wei...
# GP084C01W-G11  gap-swim-baby-maillot-de-bain-pure-red-gp084c0...
# LE224I01M-K11    levisr-sawtoo-baby-chemise-indigo-le224i01m-k11
# N1243K0A8-Q11  nike-performance-air-survetement-black-heather...
# NI114F00H-K11  nike-sportswear-lil-swoosh-baskets-basses-obsi...
# V2023E00K-J11      vingino-qalla-minijupe-violetti-v2023e00k-j11
# VA443G008-K11  vaude-kikimora-jacket-veste-polaire-radiate-bl...
#
# [20299 rows x 19 columns]

# %% [markdown]
# #### Display the trending brand in DataFrame

# %%
df.brand_name.value_counts().index[0]
# Out:
# 'Friboo'

# %% [markdown]
# #### Display the brand with maximal total discount (sum of discounts on all goods)

# %%
#Our data is still text. Convert prices into numbers:
df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')

df['price.original'] = [x.replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [x.replace(',', '.') for x in df['price.promotional']]

# %%
df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)
df1=df.copy()

# %%
total_disc=df1.groupby(['brand_name']).sum().discount_amount

# %%
total_disc.sort_values(ascending=False).index[0]
# Out:
# 'Friboo'

# %% [markdown]
# #### Display the brands without discount at all

# %%
total_disc[total_disc==0]
# Out:
# Series([], Name: discount_amount, dtype: float64)
